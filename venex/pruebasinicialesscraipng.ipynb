# %% [markdown]
# AMERICA

# %%
import pandas as pd

# %%
from selenium import webdriver
from selenium.webdriver.chrome.service import Service
from selenium.webdriver.chrome.options import Options
from selenium.webdriver.common.by import By
from selenium.common.exceptions import NoSuchElementException
from webdriver_manager.chrome import ChromeDriverManager
import time

# %%
from selenium import webdriver
from selenium.webdriver.chrome.service import Service
from selenium.webdriver.chrome.options import Options
from webdriver_manager.chrome import ChromeDriverManager
from selenium.webdriver.common.by import By
from selenium.common.exceptions import NoSuchElementException
import time
import pandas as pd

def setup_driver():
    """Configura y retorna el WebDriver."""
    chrome_options = Options()
    chrome_options.add_argument("--headless")  # Ejecuta el navegador en segundo plano
    service = Service(ChromeDriverManager().install())
    driver = webdriver.Chrome(service=service, options=chrome_options)
    return driver

def scrape_tweets(driver, url, div_class):
    """Raspa los tweets dentro de un div con la clase especificada."""
    try:
        driver.get(url)
        time.sleep(5)  # Espera a que el contenido se cargue
        
        # Encuentra el div con la clase 'ctf-tweets' usando Selenium
        tweets_container = driver.find_element(By.CLASS_NAME, div_class)
        
        # Obtiene todos los elementos de tweet dentro del contenedor
        tweets = tweets_container.find_elements(By.TAG_NAME, 'p')  # Asumiendo que los tweets están en <p>
        
        # Extrae el texto de cada tweet
        tweet_texts = [tweet.text.strip() for tweet in tweets]
        
        return tweet_texts

    except NoSuchElementException:
        return f"Elemento con clase '{div_class}' no encontrado en la página."
    except Exception as e:
        return f"Error: {e}"

def main():
    driver = setup_driver()
    
    # URL de la página de la que quieres scrapear los tweets
    url = 'https://solovenex.com'  # Cambia esto por la URL de la página que contiene los tweets
    
    # Clase del div que contiene los tweets
    div_class = 'ctf-tweets'
    
    # Scrapea los tweets
    tweets = scrape_tweets(driver, url, div_class)
    
    if isinstance(tweets, str):
        print(tweets)
    else:
        # Guarda los tweets en un archivo CSV
        df = pd.DataFrame(tweets, columns=['Tweet'])
        df.to_csv('tweets.csv', index=False)
        print("Archivo 'tweets.csv' guardado con los tweets.")
    
    driver.quit()

if __name__ == '__main__':
    main()
# Out:
# Archivo 'tweets.csv' guardado con los tweets.

# %%
df=pd.read_csv('tweets.csv')

# %%
df.head(50)
# Out:
#                                                Tweet
# 0  El mediocampista José Correa (2006) se encuent...
# 1  ¡𝗟𝗔 𝗙𝗩𝗙 𝗣𝗨𝗝𝗔 𝗣𝗢𝗥 𝗠𝗔𝗟𝗗𝗜𝗡𝗜! • 🚨🍝\n\nInforma @Nic...
# 2                                                NaN
# 3  ¡Xedny Sport 𝗦𝗜𝗘𝗠𝗣𝗥𝗘 nos acompaña!\n\nNuestros...
# 4                                                NaN
# 5  ¡𝗧𝗘 𝗟𝗟𝗘𝗩𝗔𝗠𝗢𝗦 𝗔𝗟 #𝗩𝗘𝗡 - #𝗔𝗥𝗚 !\n\n• Junto a la ...

# %%
from selenium import webdriver
from selenium.webdriver.chrome.service import Service
from selenium.webdriver.common.by import By
from selenium.webdriver.chrome.options import Options
from webdriver_manager.chrome import ChromeDriverManager
import time

def setup_driver():
    """Configura y retorna el WebDriver."""
    chrome_options = Options()
    chrome_options.add_argument("--headless")  # Ejecuta el navegador en segundo plano
    service = Service(ChromeDriverManager().install())
    driver = webdriver.Chrome(service=service, options=chrome_options)
    return driver

def scrape_tweets(driver, url):
    """Raspa los tweets desde el contenedor con clase 'ctf-tweets'."""
    driver.get(url)
    time.sleep(5)  # Espera a que el contenido se cargue

    try:
        # Encuentra el contenedor que contiene los tweets por su clase
        tweet_container = driver.find_element(By.CLASS_NAME, "ctf-tweets")
        
        # Encuentra todos los elementos que contienen tweets dentro del contenedor
        tweets = tweet_container.find_elements(By.TAG_NAME, "p")  # Ajusta el selector si los tweets no están en <p>
        
        # Extrae el texto de cada tweet
        tweet_texts = [tweet.text for tweet in tweets]
        return tweet_texts

    except Exception as e:
        return f"Error: {e}"

def main():
    driver = setup_driver()
    url = 'https://solovenex.com/'  # URL de la página que contiene los tweets
    tweets = scrape_tweets(driver, url)
    
    if isinstance(tweets, list):
        for i, tweet in enumerate(tweets):
            print(f"Tweet {i+1}: {tweet}")
    else:
        print(tweets)

    driver.quit()

if __name__ == '__main__':
    main()
# Out:
# Tweet 1: El mediocampista José Correa (2006) se encuentra en Europa, definiendo su futuro. En la postal, entrena de la mano de la academia FDC Vista, de Krasnodar.
#
# No está solo, lo acompaña Juan Campos, el delantero clase 2007 que también es ficha del @NuevaEsparta_FC.
#
# .@SOLOVENEX_
# Tweet 2: ¡𝗟𝗔 𝗙𝗩𝗙 𝗣𝗨𝗝𝗔 𝗣𝗢𝗥 𝗠𝗔𝗟𝗗𝗜𝗡𝗜! • 🚨🍝
#
# Informa @NicoSchira vía X que la @FVF_Oficial mantiene la intención de repatriar al menor de la dinastía Maldini.
#
# Sin embargo, el MC del Monza de Italia, quien ya manifestó su interés en defender a la “azzurri”, está…
# Tweet 3:
# Tweet 4: ¡Xedny Sport 𝗦𝗜𝗘𝗠𝗣𝗥𝗘 nos acompaña!
#
# Nuestros aliados engalanaron las instalaciones del Monumental de Maturín con sus prendas.
#
# Xedny es patrocinante oficial de SOLOVENEX en el camino al Mundial - 2026. ¡Cree en ti!
#
# #PoderVinotinto
# Tweet 5:
# Tweet 6: ¡𝗧𝗘 𝗟𝗟𝗘𝗩𝗔𝗠𝗢𝗦 𝗔𝗟 #𝗩𝗘𝗡 - #𝗔𝗥𝗚 !
#
# ...

# %%
from selenium import webdriver
from selenium.webdriver.chrome.service import Service
from selenium.webdriver.common.by import By
from selenium.webdriver.chrome.options import Options
from webdriver_manager.chrome import ChromeDriverManager
import time
import pandas as pd

def setup_driver():
    """Configura y retorna el WebDriver."""
    chrome_options = Options()
    chrome_options.add_argument("--headless")  # Ejecuta el navegador en segundo plano
    service = Service(ChromeDriverManager().install())
    driver = webdriver.Chrome(service=service, options=chrome_options)
    return driver

def scrape_tweets(driver, url):
    """Raspa los tweets desde el contenedor con clase 'ctf-tweets'."""
    driver.get(url)
    time.sleep(5)  # Espera a que el contenido se cargue

    try:
        # Encuentra el contenedor que contiene los tweets por su clase
        tweet_container = driver.find_element(By.CLASS_NAME, "ctf-tweets")
        
        # Encuentra todos los elementos que contienen tweets dentro del contenedor
        tweets = tweet_container.find_elements(By.TAG_NAME, "p")  # Ajusta el selector si los tweets no están en <p>
        
        # Extrae el texto de cada tweet
        tweet_texts = [tweet.text for tweet in tweets]
        return tweet_texts

    except Exception as e:
        return f"Error: {e}"

def save_tweets_to_csv(tweets, file_name):
    """Guarda los tweets en un archivo CSV."""
    if tweets:
        df = pd.DataFrame(tweets, columns=['Tweet'])
        df.to_csv(file_name, index=False)
        print(f"Tweets guardados en '{file_name}'")
    else:
        print("No se encontraron tweets para guardar.")

def main():
    driver = setup_driver()
    url = 'https://solovenex.com/'  # URL de la página que contiene los tweets
    tweets = scrape_tweets(driver, url)
    
    if isinstance(tweets, list):
        for i, tweet in enumerate(tweets):
            print(f"Tweet {i+1}: {tweet}")
        
        # Guardar los tweets en un archivo CSV
        save_tweets_to_csv(tweets, 'tweets2.csv')
    else:
        print(tweets)

    driver.quit()

if __name__ == '__main__':
    main()
# Out:
# Tweet 1: El mediocampista José Correa (2006) se encuentra en Europa, definiendo su futuro. En la postal, entrena de la mano de la academia FDC Vista, de Krasnodar.
#
# No está solo, lo acompaña Juan Campos, el delantero clase 2007 que también es ficha del @NuevaEsparta_FC.
#
# .@SOLOVENEX_
# Tweet 2: ¡𝗟𝗔 𝗙𝗩𝗙 𝗣𝗨𝗝𝗔 𝗣𝗢𝗥 𝗠𝗔𝗟𝗗𝗜𝗡𝗜! • 🚨🍝
#
# Informa @NicoSchira vía X que la @FVF_Oficial mantiene la intención de repatriar al menor de la dinastía Maldini.
#
# Sin embargo, el MC del Monza de Italia, quien ya manifestó su interés en defender a la “azzurri”, está…
# Tweet 3:
# Tweet 4: ¡Xedny Sport 𝗦𝗜𝗘𝗠𝗣𝗥𝗘 nos acompaña!
#
# Nuestros aliados engalanaron las instalaciones del Monumental de Maturín con sus prendas.
#
# Xedny es patrocinante oficial de SOLOVENEX en el camino al Mundial - 2026. ¡Cree en ti!
#
# #PoderVinotinto
# Tweet 5:
# Tweet 6: ¡𝗧𝗘 𝗟𝗟𝗘𝗩𝗔𝗠𝗢𝗦 𝗔𝗟 #𝗩𝗘𝗡 - #𝗔𝗥𝗚 !
#
# ...

# %%
from selenium import webdriver
from selenium.webdriver.chrome.service import Service
from selenium.webdriver.common.by import By
from selenium.webdriver.chrome.options import Options
from webdriver_manager.chrome import ChromeDriverManager
import time
import pandas as pd

def setup_driver():
    """Configura y retorna el WebDriver."""
    chrome_options = Options()
    chrome_options.add_argument("--headless")  # Ejecuta el navegador en segundo plano
    service = Service(ChromeDriverManager().install())
    driver = webdriver.Chrome(service=service, options=chrome_options)
    return driver

def scrape_tweets(driver, url):
    """Raspa los tweets desde el contenedor con clase específica."""
    driver.get(url)
    time.sleep(5)  # Espera a que el contenido se cargue

    try:
        # Encuentra el nuevo contenedor por su clase
        tweet_container = driver.find_element(By.CLASS_NAME, "fusion-layout-column")
        
        # Encuentra todos los elementos que contienen tweets dentro del contenedor
        tweets = tweet_container.find_elements(By.TAG_NAME, "div")  # Ajusta si los tweets no están en <p>
        
        # Extrae el texto de cada tweet
        tweet_texts = [tweet.text for tweet in tweets]
        return tweet_texts

    except Exception as e:
        return f"Error: {e}"

def save_tweets_to_csv(tweets, file_name):
    """Guarda los tweets en un archivo CSV."""
    if tweets:
        df = pd.DataFrame(tweets, columns=['Tweet'])
        df.to_csv(file_name, index=False)
        print(f"Tweets guardados en '{file_name}'")
    else:
        print("No se encontraron tweets para guardar.")

def main():
    driver = setup_driver()
    url = 'https://solovenex.com/'  # URL de la página que contiene los tweets
    tweets = scrape_tweets(driver, url)
    
    if isinstance(tweets, list):
        for i, tweet in enumerate(tweets):
            print(f"Tweet {i+1}: {tweet}")
        
        # Guardar los tweets en un archivo CSV
        save_tweets_to_csv(tweets, 'tweets3.csv')
    else:
        print(tweets)

    driver.quit()

if __name__ == '__main__':
    main()
# Out:
# Tweet 1:
# Tweet 2:
# Tweet 3:
# Tweets guardados en 'tweets3.csv'
