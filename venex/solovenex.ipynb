# %% [markdown]
# Instalo ntscraper y cloud para scrapear twitter y combinarlo con gemini

# %%
##pip install ntscraper   # DOCU https://pypi.org/project/ntscraper/

# %%
#conecto el colab de mi usuario
#import sys

# Additional authentication is required for Google Colab
#if "google.colab" in sys.modules:
    # Authenticate user to Google Cloud
#    from google.colab import auth

#    auth.authenticate_user()

# %%
pip install ntscraper
# Out:
# Collecting ntscraper
#   Downloading ntscraper-0.3.17-py3-none-any.whl.metadata (7.4 kB)
# Requirement already satisfied: requests>=2.28 in c:\users\flori\appdata\local\programs\python\python312\lib\site-packages (from ntscraper) (2.32.3)
# Requirement already satisfied: beautifulsoup4>=4.11 in c:\users\flori\appdata\local\programs\python\python312\lib\site-packages (from ntscraper) (4.12.3)
# Requirement already satisfied: lxml>=4.9 in c:\users\flori\appdata\local\programs\python\python312\lib\site-packages (from ntscraper) (5.3.0)
# Requirement already satisfied: tqdm>=4.66 in c:\users\flori\appdata\local\programs\python\python312\lib\site-packages (from ntscraper) (4.66.5)
# Requirement already satisfied: soupsieve>1.2 in c:\users\flori\appdata\local\programs\python\python312\lib\site-packages (from beautifulsoup4>=4.11->ntscraper) (2.6)
# Requirement already satisfied: charset-normalizer<4,>=2 in c:\users\flori\appdata\local\programs\python\python312\lib\site-packages (from requests>=2.28->ntscraper) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\flori\appdata\local\programs\python\python312\lib\site-packages (from requests>=2.28->ntscraper) (3.8)
# Requirement already satisfied: urllib3<3,>=1.21.1 in c:\users\flori\appdata\local\programs\python\python312\lib\site-packages (from requests>=2.28->ntscraper) (2.2.2)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\flori\appdata\local\programs\python\python312\lib\site-packages (from requests>=2.28->ntscraper) (2024.8.30)
# Requirement already satisfied: colorama in c:\users\flori\appdata\roaming\python\python312\site-packages (from tqdm>=4.66->ntscraper) (0.4.6)
# Downloading ntscraper-0.3.17-py3-none-any.whl (12 kB)
# Installing collected packages: ntscraper
# Successfully installed ntscraper-0.3.17
# Note: you may need to restart the kernel to use updated packages.

# %%
from ntscraper import Nitter
import pandas as pd
from datetime import datetime

# %%
from pprint import pprint

# %%
scraper = Nitter (log_level=1, skip_instance_check=False)
# Out:
# Testing instances: 100%|██████████| 16/16 [00:29<00:00,  1.87s/it]

# %% [markdown]
# Pruebo funcion get_tweets

# %% [markdown]
# #PARAMETROS DE LA FUNCION GET_TWEETS
# * term: search term
# * mode: modality to scrape the tweets. Default is 'term' which will look for tweets containing the search term. Other modes are 'hashtag' to search for a hashtag and 'user' to scrape tweets from a user profile
# * number: number of tweets to scrape. Default is -1 (no limit).
# * since: date to start scraping from, formatted as YYYY-MM-DD. Default is None
# * until: date to stop scraping at, formatted as YYYY-MM-DD. Default is None
# * near: location to search tweets from. Default is None (anywhere)
# * language: language of the tweets to search. Default is None (any language). The language must be specified as a 2-letter ISO 639-1 code (e.g. 'en' for English, 'es' for Spanish, 'fr' for French ...)
# * to: user to which the tweets are directed. Default is None (any user). For example, if you want to search for tweets directed to @github, you would set this parameter to 'github'
# * filters: list of filters to apply to the search. Default is None. Valid filters are: 'nativeretweets', 'media', 'videos', 'news', 'verified', 'native_video', 'replies', 'links', 'images', 'safe', 'quote', 'pro_video'
# * exclude: list of filters to exclude from the search. Default is None. Valid filters are the same as above
# * max_retries: max retries to scrape a page. Default is 5
# * instance: Nitter instance to use. Default is None and will be chosen at random

# %% [markdown]
# Algunos ejemplos para probar

# %%
#tweets=scraper.get_tweets("solovenex", mode="user", number=100)
# Out:
# INFO:root:No instance specified, using random instance https://nitter.lucabased.xyz
# WARNING:root:Fetching error: User "solovenex" has been suspended

# %%
tweets2 = scraper.get_tweets("solovenex_", mode = "user", since = "2024-01-01")
tweets2
# Out:
# 23-Sep-24 12:08:25 - No instance specified, using random instance https://nitter.lucabased.xyz
# 23-Sep-24 12:08:36 - Current stats for solovenex_: 14 tweets, 0 threads...
# 23-Sep-24 12:08:44 - Current stats for solovenex_: 27 tweets, 0 threads...
# 23-Sep-24 12:08:49 - Current stats for solovenex_: 38 tweets, 0 threads...
# 23-Sep-24 12:08:54 - Current stats for solovenex_: 48 tweets, 0 threads...
# 23-Sep-24 12:08:59 - Current stats for solovenex_: 63 tweets, 0 threads...
# 23-Sep-24 12:09:04 - Current stats for solovenex_: 73 tweets, 0 threads...
# 23-Sep-24 12:09:09 - Current stats for solovenex_: 85 tweets, 0 threads...
# 23-Sep-24 12:09:14 - Current stats for solovenex_: 100 tweets, 0 threads...
# 23-Sep-24 12:09:19 - Current stats for solovenex_: 113 tweets, 0 threads...
# 23-Sep-24 12:09:25 - Current stats for solovenex_: 125 tweets, 0 threads...
# 23-Sep-24 12:09:29 - Current stats for solovenex_: 136 tweets, 0 threads...
# 23-Sep-24 12:09:34 - Current stats for solovenex_: 146 tweets, 0 threads...
# 23-Sep-24 12:09:39 - Current stats for solovenex_: 157 tweets, 0 threads...
# 23-Sep-24 12:09:45 - Current stats for solovenex_: 168 tweets, 0 threads...
# 23-Sep-24 12:09:51 - Current stats for solovenex_: 181 tweets, 0 threads...
# 23-Sep-24 12:09:57 - Current stats for solovenex_: 190 tweets, 0 threads...
# 23-Sep-24 12:10:03 - Current stats for solovenex_: 202 tweets, 0 threads...
# 23-Sep-24 12:10:08 - Current stats for solovenex_: 216 tweets, 0 threads...
# 23-Sep-24 12:10:12 - Current stats for solovenex_: 225 tweets, 0 threads...
# 23-Sep-24 12:10:17 - Current stats for solovenex_: 243 tweets, 0 threads...
# 23-Sep-24 12:10:21 - Current stats for solovenex_: 252 tweets, 0 threads...
# 23-Sep-24 12:10:29 - Current stats for solovenex_: 265 tweets, 0 threads...
# 23-Sep-24 12:10:34 - Current stats for solovenex_: 277 tweets, 0 threads...
# 23-Sep-24 12:10:38 - Current stats for solovenex_: 291 tweets, 0 threads...
# 23-Sep-24 12:10:43 - Current stats for solovenex_: 304 tweets, 0 threads...
# 23-Sep-24 12:10:48 - Current stats for solovenex_: 320 tweets, 0 threads...
# 23-Sep-24 12:10:52 - Current stats for solovenex_: 330 tweets, 0 threads...
# 23-Sep-24 12:10:59 - Current stats for solovenex_: 341 tweets, 0 threads...
# 23-Sep-24 12:11:03 - Current stats for solovenex_: 355 tweets, 0 threads...
# 23-Sep-24 12:11:08 - Current stats for solovenex_: 370 tweets, 0 threads...
# 23-Sep-24 12:11:12 - Current stats for solovenex_: 381 tweets, 0 threads...
# 23-Sep-24 12:11:16 - Current stats for solovenex_: 395 tweets, 0 threads...
# 23-Sep-24 12:11:21 - Current stats for solovenex_: 411 tweets, 0 threads...
# 23-Sep-24 12:11:26 - Current stats for solovenex_: 421 tweets, 0 threads...
# 23-Sep-24 12:11:31 - Current stats for solovenex_: 434 tweets, 0 threads...
# 23-Sep-24 12:11:36 - Current stats for solovenex_: 445 tweets, 0 threads...
# 23-Sep-24 12:11:41 - Current stats for solovenex_: 458 tweets, 0 threads...
# 23-Sep-24 12:11:45 - Current stats for solovenex_: 475 tweets, 0 threads...
# 23-Sep-24 12:11:50 - Current stats for solovenex_: 485 tweets, 0 threads...
# 23-Sep-24 12:11:54 - Current stats for solovenex_: 497 tweets, 0 threads...
# 23-Sep-24 12:12:01 - Current stats for solovenex_: 514 tweets, 0 threads...
# 23-Sep-24 12:12:03 - Fetching error: Instance has been rate limited.Use another instance or try again later.
# {'tweets': [{'link': 'https://twitter.com/SOLOVENEX_/status/1837618723538014486#m',
#    'text': 'Somos venezolanos. ¡Somos hermanos!   𝘼𝙍𝘼𝙈𝘽𝙐𝙍𝙐 🔗 𝙈𝘼𝘾𝙃𝙄́𝙎 = 🫂❤️🇻🇪  #VenEx',
#    'user': {'name': 'SOLOVENEX',
#     'username': '@SOLOVENEX_',
#     'profile_id': '1812834507617124352',
#     'avatar': 'https://pbs.twimg.com/profile_images/1812834507617124352/nSbyIO4J_bigger.jpg'},
#    'date': 'Sep 21, 2024 · 10:23 PM UTC',
#    'is-retweet': True,
#    'is-pinned': False,
#    'external-link': '',
#    'replying-to': [],
#    'quoted-post': {},
#    'stats': {'comments': 3, 'retweets': 75, 'quotes': 1, 'likes': 762},
#    'pictures': ['https://pbs.twimg.com/media/GYCIe3wXMAAa2eq.jpg'],
#    'videos': [],
#    'gifs': []},
#   {'link': 'https://twitter.com/SOLOVENEX_/status/1837883159553208575#m',
#    'text': 'No dejemos ir este momento (😂)   ¡Comenta si tienes un pana así! ⬇️  | 🎥 Vía: @Lavinotintopod |',
#    'user': {'name': 'SOLOVENEX',
#     'username': '@SOLOVENEX_',
#     'profile_id': '1812834507617124352',
#     'avatar': 'https://pbs.twimg.com/profile_images/1812834507617124352/nSbyIO4J_bigger.jpg'},
#    'date': 'Sep 22, 2024 · 3:54 PM UTC',
#    'is-retweet': False,
#    'is-pinned': False,
#    'external-link': '',
#    'replying-to': [],
#    'quoted-post': {},
#    'stats': {'comments': 0, 'retweets': 1, 'quotes': 0, 'likes': 3},
#    'pictures': [],
#    'videos': ['https://video.twimg.com/amplify_video/1837883091748012032/pl/rRepCmym90IvpMvx.m3u8?tag=16'],
#    'gifs': []},
#   {'link': 'https://twitter.com/SOLOVENEX_/status/1837660758093844989#m',
#    'text': '𝗝𝗛𝗢𝗡𝗗𝗘𝗥 𝗖𝗔́𝗗𝗜𝗭 continúa siendo factor diferencial con el Club León en la Liga MX y este sábado definió la victoria 1-0 sobre Atlético San Luis.   El delantero caraqueño disputó 66’ minutos y anotó su 𝗤𝗨𝗜𝗡𝗧𝗢 𝗚𝗢𝗟 en ocho partidos con ‘los felinos’.  .@SofascoreLA valoró su actuación en 7.4 siendo uno de los mejores de su equipo y consolidándose como uno de los ‘9’  más efectivos del fútbol mexicano.   “¡𝗧𝗥𝗔𝗡𝗤𝗨𝗜𝗟𝗢𝗦, 𝗬𝗢 𝗘𝗦𝗧𝗢𝗬 𝗔𝗤𝗨𝗜́!” — 🇻🇪  #VenEx #LigaMX #Cádiz #SoloVenex   | 📸 @clubleonfc |',
#    'user': {'name': 'SOLOVENEX',
#     'username': '@SOLOVENEX_',
#     'profile_id': '1812834507617124352',
#     'avatar': 'https://pbs.twimg.com/profile_images/1812834507617124352/nSbyIO4J_bigger.jpg'},
#    'date': 'Sep 22, 2024 · 1:10 AM UTC',
#    'is-retweet': False,
#    'is-pinned': False,
#    'external-link': '',
#    'replying-to': [],
#    'quoted-post': {},
#    'stats': {'comments': 0, 'retweets': 26, 'quotes': 0, 'likes': 250},
#    'pictures': ['https://pbs.twimg.com/media/GYCutGOW4AAkcAF.jpg'],
#    'videos': [],
#    'gifs': []},
#   {'link': 'https://twitter.com/clubleonfc/status/1837648994803065343#m',
#    'text': '¡GOOOOOOOOOOOOOOOL DE LA FIEEEEERA!  ¡GRÍTALO CON @Telcel!',
#    'user': {'name': 'Club León',
#     'username': '@clubleonfc',
#     'profile_id': '1825880916436160512',
#     'avatar': 'https://pbs.twimg.com/profile_images/1825880916436160512/K5lxWYth_bigger.jpg'},
#    'date': 'Sep 22, 2024 · 12:23 AM UTC',
#    'is-retweet': True,
#    'is-pinned': False,
#    'external-link': '',
#    'replying-to': [],
#    'quoted-post': {},
#    'stats': {'comments': 18, 'retweets': 20, 'quotes': 4, 'likes': 370},
#    'pictures': [],
#    'videos': ['https://video.twimg.com/ext_tw_video/1837648961722560512/pu/pl/Id7vlgiZg-UFQf7S.m3u8?tag=12'],
#    'gifs': []},
#   {'link': 'https://twitter.com/SOLOVENEX_/status/1837508611389444545#m',
#    'text': '“𝗔 𝗺𝗶 𝗺𝗲 𝗽𝗮𝗿𝗲𝗰𝗲 𝘂𝗻𝗮 𝗶𝗿𝗿𝗲𝘀𝗽𝗼𝗻𝘀𝗮𝗯𝗶𝗹𝗶𝗱𝗮𝗱 𝘀𝘂𝗯𝗶𝗿 𝗮 𝗹𝗮 𝗮𝗹𝘁𝘂𝗿𝗮 𝘆 𝗻𝗼 𝘁𝗼𝗺𝗮𝗿 𝘂𝗻 𝘁𝗶𝗽𝗼 𝗱𝗲 𝗽𝗿𝗲𝘃𝗶𝘀𝗶𝗼́𝗻”. 🎙️🔥🇻🇪  La palabra de César Farías a @JOSEHUGOILLERA sobre el factor altura. “Venezuela lo acaba de pagar muy caro”, declaró el estratega en esta entrevista.  La @SeleVinotinto viene de caer 4-0 en El Alto (vs Bolivia) por las Eliminatorias CONMEBOL.   📲 • ¡Te leemos en los comentarios! ⬇️  #Vinotinto #Farías #Video #SoloVenex',
#    'user': {'name': 'SOLOVENEX',
#     'username': '@SOLOVENEX_',
#     'profile_id': '1812834507617124352',
#     'avatar': 'https://pbs.twimg.com/profile_images/1812834507617124352/nSbyIO4J_bigger.jpg'},
#    'date': 'Sep 21, 2024 · 3:06 PM UTC',
#    'is-retweet': True,
#    'is-pinned': False,
#    'external-link': '',
#    'replying-to': [],
#    'quoted-post': {},
#    'stats': {'comments': 30, 'retweets': 60, 'quotes': 18, 'likes': 280},
#    'pictures': [],
#    'videos': ['https://video.twimg.com/amplify_video/1837508546935603200/pl/wk2hzGTLua4eEQnU.m3u8?tag=16&v=e9a'],
#    'gifs': []},
#   {'link': 'https://twitter.com/SOLOVENEX_/status/1837618785487905231#m',
#    'text': '| 📸 @RealSociedad |',
#    'user': {'name': 'SOLOVENEX',
#     'username': '@SOLOVENEX_',
#     'profile_id': '1812834507617124352',
#     'avatar': 'https://pbs.twimg.com/profile_images/1812834507617124352/nSbyIO4J_bigger.jpg'},
#    'date': 'Sep 21, 2024 · 10:23 PM UTC',
#    'is-retweet': False,
#    'is-pinned': False,
#    'external-link': '',
#    'replying-to': [],
#    'quoted-post': {},
#    'stats': {'comments': 0, 'retweets': 0, 'quotes': 0, 'likes': 1},
#    'pictures': [],
#    'videos': [],
#    'gifs': []},
#   {'link': 'https://twitter.com/SOLOVENEX_/status/1837614128396972102#m',
#    'text': '🇻🇪 𝗝𝗢𝗡 𝗠𝗜𝗞𝗘𝗟 𝗔𝗥𝗔𝗠𝗕𝗨𝗥𝗨 sigue completando buenas actuaciones en LaLiga con la @RealSociedad y este sábado no fue la excepción en el empate 0-0 con el @realvalladolid de Machís.   El lateral derecho venezolano jugó los 90’ minutos y fue el segundo mejor valorado de su equipo por la reconocida APP @sofascorela con 𝟳.𝟳 𝗣𝗨𝗡𝗧𝗢𝗦.  𝗡𝗔𝗗𝗜𝗘 en su equipo ganó más duelos que él [8/12] y fue el jugador que más ocasiones generó [03].  📊 • 𝗧𝗮𝗺𝗯𝗶𝗲́𝗻 𝗱𝗲𝗷𝗼́ 𝗹𝗼𝘀 𝘀𝗶𝗴𝘂𝗶𝗲𝗻𝘁𝗲𝘀 𝗻𝘂́𝗺𝗲𝗿𝗼𝘀:  ➤ 80% en pases precisos. ➤ 03 pases claves. ➤ 03 despejes completados.  ➤ 02 disparos bloqueados.  .@JonAramburu3 como @parley.com.ve, las gana todas fácil, rápido y seguro. ¡𝗕𝗘𝗦𝗧𝗜𝗔 𝗗𝗘𝗙𝗘𝗡𝗦𝗜𝗩𝗔!',
#    'user': {'name': 'SOLOVENEX',
#     'username': '@SOLOVENEX_',
#     'profile_id': '1812834507617124352',
#     'avatar': 'https://pbs.twimg.com/profile_images/1812834507617124352/nSbyIO4J_bigger.jpg'},
#    'date': 'Sep 21, 2024 · 10:05 PM UTC',
#    'is-retweet': False,
#    'is-pinned': False,
#    'external-link': '',
#    'replying-to': [],
#    'quoted-post': {},
#    'stats': {'comments': 0, 'retweets': 3, 'quotes': 0, 'likes': 23},
#    'pictures': ['https://pbs.twimg.com/media/GYCETTsWoAAl9S8.jpg',
#     'https://pbs.twimg.com/media/GYCETToXUAAG_3B.jpg'],
#    'videos': [],
#    'gifs': []},
#   {'link': 'https://twitter.com/SOLOVENEX_/status/1837317464524476486#m',
#    'text': '¡𝗥𝗢𝗡𝗗𝗢́𝗡 𝗘𝗡 𝗦𝗨 𝗦𝗔𝗟𝗦𝗔! 🇻🇪  Así marcó su 11º gol en la Liga MX con el Pachuca, que iguala de manera transitoria 2-2 con Puebla.  ‘El gladiador’ venezolano ya suma 24 goles en 2024. Ningún jugador que haga vida en el fútbol mexicano ha anotado más goles que él en el calendario natural.  Además, es el cuarto futbolista venezolano con más tantos en la máxima categoría mexicana, superado por: Giancarlo Maldonado (44), Juan Arango (41) y Fernando Aristeguieta, quien suma 25. 𝗜𝗡𝗔𝗚𝗢𝗧𝗔𝗕𝗟𝗘.  #VenEx #LigaMX #Rondón #SoloVenex   | 🎥 Vía: @TuzosOficial |',
#    'user': {'name': 'SOLOVENEX',
#     'username': '@SOLOVENEX_',
#     'profile_id': '1812834507617124352',
#     'avatar': 'https://pbs.twimg.com/profile_images/1812834507617124352/nSbyIO4J_bigger.jpg'},
#    'date': 'Sep 21, 2024 · 2:26 AM UTC',
#    'is-retweet': False,
#    'is-pinned': False,
#    'external-link': '',
#    'replying-to': [],
#    'quoted-post': {},
#    'stats': {'comments': 1, 'retweets': 13, 'quotes': 1, 'likes': 85},
#    'pictures': [],
#    'videos': ['https://video.twimg.com/amplify_video/1837317267316424704/pl/hTtiksUdHfAxbY-w.m3u8?tag=16'],
#    'gifs': []},
#   {'link': 'https://twitter.com/SOLOVENEX_/status/1837236188089868356#m',
#    'text': '👴🏻',
#    'user': {'name': 'SOLOVENEX',
#     'username': '@SOLOVENEX_',
#     'profile_id': '1812834507617124352',
#     'avatar': 'https://pbs.twimg.com/profile_images/1812834507617124352/nSbyIO4J_bigger.jpg'},
#    'date': 'Sep 20, 2024 · 9:03 PM UTC',
#    'is-retweet': False,
#    'is-pinned': False,
#    'external-link': '',
#    'replying-to': ['@StefanoMalaveM'],
#    'quoted-post': {},
#    'stats': {'comments': 1, 'retweets': 0, 'quotes': 0, 'likes': 1},
#    'pictures': [],
#    'videos': [],
#    'gifs': []},
#   {'link': 'https://twitter.com/carlostaracher/status/1837228099831845241#m',
#    'text': 'A quienes tenemos años trabajando para que cosas como estas sucedan, se nos infla el pecho. Parece simple, pero “detallitos” como este hablan mucho de que algunas cosas están cambiando.   Machís y Aramburu en el afiche promocional del #RealValladolidRealSociedad. ¡Qué orgullo! 🇻🇪',
#    'user': {'name': 'Carlos Tarache',
#     'username': '@carlostaracher',
#     'profile_id': '1826421340812791808',
#     'avatar': 'https://pbs.twimg.com/profile_images/1826421340812791808/xtKkoBMm_bigger.jpg'},
#    'date': 'Sep 20, 2024 · 8:31 PM UTC',
#    'is-retweet': True,
#    'is-pinned': False,
#    'external-link': '',
#    'replying-to': [],
#    'quoted-post': {'link': 'https://twitter.com/RealSociedad/status/1837205084696105362#m',
#     'text': '🎥 𝗣𝗿𝗲𝗽𝗮𝗿𝗮𝗱𝗼𝘀 para el inicio del @sansebastianfes #RealValladolidRealSociedad',
#     'user': {'name': 'Real Sociedad Fútbol',
#      'username': '@RealSociedad',
#      'profile_id': '1806965321032519680',
#      'avatar': 'https://pbs.twimg.com/profile_images/1806965321032519680/upcVcCAo_mini.jpg'},
#     'date': 'Sep 20, 2024 · 7:00 PM UTC',
#     'pictures': ['https://pbs.twimg.com/media/GX1mQQrXEAAf7pN.jpg'],
#     'videos': [],
#     'gifs': []},
#    'stats': {'comments': 8, 'retweets': 92, 'quotes': 0, 'likes': 601},
#    'pictures': [],
#    'videos': [],
#    'gifs': []},
#   {'link': 'https://twitter.com/SOLOVENEX_/status/1837164351058334127#m',
#    'text': 'A nombre de Xedny Sport: “¡𝗰𝗿𝗲𝗲 𝗲𝗻 𝘁𝗶!”  https://www.instagram.com/xednysport?igsh=eXR4OWwxZTU0c2V1',
#    'user': {'name': 'SOLOVENEX',
#     'username': '@SOLOVENEX_',
#     'profile_id': '1812834507617124352',
#     'avatar': 'https://pbs.twimg.com/profile_images/1812834507617124352/nSbyIO4J_bigger.jpg'},
#    'date': 'Sep 20, 2024 · 4:18 PM UTC',
#    'is-retweet': False,
#    'is-pinned': False,
#    'external-link': '',
#    'replying-to': [],
#    'quoted-post': {},
#    'stats': {'comments': 0, 'retweets': 0, 'quotes': 0, 'likes': 1},
#    'pictures': [],
#    'videos': [],
#    'gifs': []},
#   {'link': 'https://twitter.com/SOLOVENEX_/status/1837163891912016274#m',
#    'text': 'Los nuevos socios de David Martínez y José “Brujo” Martínez en #LAFC y #Corinthians: Olivier #Giroud y el neerlandés Memphis #Depay. 𝗙𝗢𝗢𝗢𝗥𝗠𝗜𝗗𝗔𝗕𝗟𝗘 (🎵)  #VenEx #MLS #Brasileirao #SoloVenex',
#    'user': {'name': 'SOLOVENEX',
#     'username': '@SOLOVENEX_',
#     'profile_id': '1812834507617124352',
#     'avatar': 'https://pbs.twimg.com/profile_images/1812834507617124352/nSbyIO4J_bigger.jpg'},
#    'date': 'Sep 20, 2024 · 4:16 PM UTC',
#    'is-retweet': False,
#    'is-pinned': False,
#    'external-link': '',
#    'replying-to': [],
#    'quoted-post': {},
#    'stats': {'comments': 3, 'retweets': 32, 'quotes': 0, 'likes': 261},
#    'pictures': ['https://pbs.twimg.com/media/GX7q0D0XEAYHYDE.jpg'],
#    'videos': [],
#    'gifs': []},
#   {'link': 'https://twitter.com/SOLOVENEX_/status/1837124256066355653#m',
#    'text': 'De criarse en el barrio El Viñedo, uno de los más peligrosos de su ciudad, a firmar con un equipo del fútbol europeo. Es es la historia de @deividtegues: una escrita a base de superación.  El Sochi ruso abre sus puertas al delantero categoría ‘2004’ tras su etapa de formación en el #FUTVE con Deportivo Anzoátegui y el Deportivo Táchira.   ¡𝗦𝗢𝗡 𝗟𝗢𝗦 𝗦𝗨𝗘𝗡̃𝗢𝗦 𝗤𝗨𝗘 𝗦𝗘 𝗖𝗨𝗠𝗣𝗟𝗘𝗡! 🩵  #VenEx #Motivación #Tegues #SoloVenex',
#    'user': {'name': 'SOLOVENEX',
#     'username': '@SOLOVENEX_',
#     'profile_id': '1812834507617124352',
#     'avatar': 'https://pbs.twimg.com/profile_images/1812834507617124352/nSbyIO4J_bigger.jpg'},
#    'date': 'Sep 20, 2024 · 1:38 PM UTC',
#    'is-retweet': False,
#    'is-pinned': False,
#    'external-link': '',
#    'replying-to': [],
#    'quoted-post': {},
#    'stats': {'comments': 0, 'retweets': 0, 'quotes': 0, 'likes': 4},
#    'pictures': ['https://pbs.twimg.com/media/GX7FAwoXIAANBfg.jpg'],
#    'videos': [],
#    'gifs': []},
#   {'link': 'https://twitter.com/SOLOVENEX_/status/1836788008357417004#m',
#    'text': '‘𝗦𝗔𝗩𝗔’: ¡𝗘𝗟 𝗠𝗔́𝗦 𝗩𝗔𝗟𝗜𝗢𝗦𝗢! 🇻🇪  @QSavarino10 fue elegido el #HeroOfTheMatch este miércoles en el 0-0 entre @Botafogo y @SaoPauloFC por la ida de los cuartos de final de la Libertadores.   El maracucho fue titular y jugó completo en el duelo ante el equipo de Nahuel Ferraresi:   ➤ 0️⃣3️⃣ pases claves. ➤ 0️⃣1️⃣ tiro a puerta (remate al palo)  ➤ 2️⃣1️⃣ pases precisos de 25 (84%) ➤ 9️⃣0️⃣ minutos disputados.   𝗗𝗜𝗙𝗘𝗥𝗘𝗡𝗖𝗜𝗔𝗟 y pieza 𝗖𝗟𝗔𝗩𝗘 = #JS10 ⚡️  #VenEx #Savarino #Libertadores #SoloVenex  | 📸 @Libertadores | 📊 @idiomafutve |',
#    'user': {'name': 'SOLOVENEX',
#     'username': '@SOLOVENEX_',
#     'profile_id': '1812834507617124352',
#     'avatar': 'https://pbs.twimg.com/profile_images/1812834507617124352/nSbyIO4J_bigger.jpg'},
#    'date': 'Sep 19, 2024 · 3:22 PM UTC',
#    'is-retweet': False,
#    'is-pinned': False,
#    'external-link': '',
#    'replying-to': [],
#    'quoted-post': {},
#    'stats': {'comments': 0, 'retweets': 0, 'quotes': 0, 'likes': 8},
#    'pictures': ['https://pbs.twimg.com/media/GX2U5hiWUAAjqsO.jpg'],
#    'videos': [],
#    'gifs': []},
#   {'link': 'https://twitter.com/LAFC/status/1836616613468213733#m',
#    'text': "62' | GOAAALLL DAVID MARTÍNEZ  #LAFCvATX 1-1",
#    'user': {'name': 'LAFC',
#     'username': '@LAFC',
#     'profile_id': '1765532048666787841',
#     'avatar': 'https://pbs.twimg.com/profile_images/1765532048666787841/uEXaV0TC_bigger.jpg'},
#    'date': 'Sep 19, 2024 · 4:01 AM UTC',
#    'is-retweet': True,
#    'is-pinned': False,
#    'external-link': '',
#    'replying-to': [],
#    'quoted-post': {},
#    'stats': {'comments': 11, 'retweets': 15, 'quotes': 1, 'likes': 193},
#    'pictures': [],
#    'videos': ['https://video.twimg.com/ext_tw_video/1836616565548290048/pu/pl/NYUkW8OQxe6ZFLtK.m3u8?tag=14'],
#    'gifs': []},
#   {'link': 'https://twitter.com/SOLOVENEX_/status/1836731886330126485#m',
#    'text': '𝗗𝗔𝗩𝗜𝗗 𝗠𝗔𝗥𝗧𝗜́𝗡𝗘𝗭 anotó este miércoles su segundo gol desde que hace vida en la @MLS. Lo hizo en el 1-1 entre su @LAFC y Austin FC.   El ex Monagas ingresó al 60’ y anotó al 62’ el tanto que definiría la paridad definitiva en el marcador y que representaría 𝘀𝘂 𝘀𝗲𝗴𝘂𝗻𝗱𝗮 𝗰𝗼𝗻𝗾𝘂𝗶𝘀𝘁𝗮 𝗲𝗻 𝘀𝘂𝗲𝗹𝗼 𝗻𝗼𝗿𝘁𝗲𝗮𝗺𝗲𝗿𝗶𝗰𝗮𝗻𝗼 𝗲𝗻 𝟭𝟴𝟮’ 𝗺𝗶𝗻𝘂𝘁𝗼𝘀 𝗱𝗲𝘀𝗱𝗲 𝗾𝘂𝗲 𝗹𝗹𝗲𝗴𝗼́ 𝗽𝗼𝗿 𝘂𝗻𝗮 𝗰𝗶𝗳𝗿𝗮 𝗿𝗲́𝗰𝗼𝗿𝗱 𝗱𝗲𝘀𝗱𝗲 𝗲𝗹 𝗙𝗨𝗧𝗩𝗘 a principios de año.   Por la visita, el volante @danipereira121 fue titular y salió sustituido al minuto 82’.  #VenEx #MLS #LAFC #SoloVenex   | 📸 @LAFC |',
#    'user': {'name': 'SOLOVENEX',
#     'username': '@SOLOVENEX_',
#     'profile_id': '1812834507617124352',
#     'avatar': 'https://pbs.twimg.com/profile_images/1812834507617124352/nSbyIO4J_bigger.jpg'},
#    'date': 'Sep 19, 2024 · 11:39 AM UTC',
#    'is-retweet': False,
#    'is-pinned': False,
#    'external-link': '',
#    'replying-to': [],
#    'quoted-post': {},
#    'stats': {'comments': 0, 'retweets': 0, 'quotes': 0, 'likes': 10},
#    'pictures': ['https://pbs.twimg.com/media/GX1h18UWUAAps7h.jpg',
#     'https://pbs.twimg.com/media/GX1h18UXQAEeE-N.jpg'],
#    'videos': [],
#    'gifs': []},
#   {'link': 'https://twitter.com/SOLOVENEX_/status/1836458309840199818#m',
#    'text': '🇻🇪 𝗝𝗨𝗔𝗡 𝗔𝗥𝗔𝗡𝗚𝗢 𝗝𝗥 (𝟮𝟬𝟬𝟲) escribió su nombre en los libros de historia del Girona al convertirse en el 𝗣𝗥𝗜𝗠𝗘𝗥 jugador que consigue anotar en UEFA Youth League con el elenco catalán (debutantes).  El hijo del mítico 18 portó el ‘9’ y lideró la victoria de los suyos 0-2 sobre el #PSG en el inicio del máximo torneo juvenil de clubes en el viejo continente. Es real. ¡𝗟𝗔 𝗗𝗜𝗡𝗔𝗦𝗧𝗜́𝗔 𝗖𝗢𝗡𝗧𝗜𝗡𝗨́𝗔!   Regístrate en WWW.PARLEY.COM.VE con nuestro código y gana el 50% de tu primera recarga.   #VenEx #Arango #UYL #SoloVenex',
#    'user': {'name': 'SOLOVENEX',
#     'username': '@SOLOVENEX_',
#     'profile_id': '1812834507617124352',
#     'avatar': 'https://pbs.twimg.com/profile_images/1812834507617124352/nSbyIO4J_bigger.jpg'},
#    'date': 'Sep 18, 2024 · 5:32 PM UTC',
#    'is-retweet': False,
#    'is-pinned': False,
#    'external-link': '',
#    'replying-to': [],
#    'quoted-post': {},
#    'stats': {'comments': 0, 'retweets': 4, 'quotes': 0, 'likes': 17},
#    'pictures': ['https://pbs.twimg.com/media/GXxpF0pWMAAFv0p.jpg'],
#    'videos': [],
#    'gifs': []},
#   {'link': 'https://twitter.com/SOLOVENEX_/status/1836146859422945773#m',
#    'text': '¡Ya son 𝟭𝟬𝟬 batallas con el Parma! 🇻🇪  El barinés Yordan Osorio sigue haciendo historia con el @1913parmacalcio de Italia (⚔️).  #VenEx #SerieA #Osorio #SoloVenex',
#    'user': {'name': 'SOLOVENEX',
#     'username': '@SOLOVENEX_',
#     'profile_id': '1812834507617124352',
#     'avatar': 'https://pbs.twimg.com/profile_images/1812834507617124352/nSbyIO4J_bigger.jpg'},
#    'date': 'Sep 17, 2024 · 8:54 PM UTC',
#    'is-retweet': False,
#    'is-pinned': False,
#    'external-link': '',
#    'replying-to': [],
#    'quoted-post': {},
#    'stats': {'comments': 5, 'retweets': 138, 'quotes': 5, 'likes': 1031},
#    'pictures': [],
#    'videos': ['https://video.twimg.com/amplify_video/1836146533030359040/pl/_ll_S9lAFdroiDfT.m3u8?tag=16&v=cfc'],
#    'gifs': []},
#   {'link': 'https://twitter.com/1x_venezuela/status/1835729234737668256#m',
#    'text': 'Regresa la #ChampionsLeague 🏆⚽️  Mañana inicia el torneo de clubes más importante del mundo y por ese motivo te traemos un pequeño hilo 🧵 con puros golazos anotados en la competición 🔥  Síguenos en todas nuestras redes como 1x_Venezuela y no te pierdas el mejor contenido 😎📲',
#    'user': {'name': '1xBet Venezuela 🇻🇪',
#     'username': '@1x_venezuela',
#     'profile_id': '1795850115317379073',
#     'avatar': 'https://pbs.twimg.com/profile_images/1795850115317379073/synfGpp0_bigger.jpg'},
#    'date': 'Sep 16, 2024 · 5:15 PM UTC',
#    'is-retweet': True,
#    'is-pinned': False,
#    'external-link': '',
#    'replying-to': [],
#    'quoted-post': {},
#    'stats': {'comments': 1, 'retweets': 26, 'quotes': 0, 'likes': 57},
#    'pictures': ['https://pbs.twimg.com/media/GXnSAlDXoAAmvxE.jpg'],
#    'videos': [],
#    'gifs': []},
#   {'link': 'https://twitter.com/SOLOVENEX_/status/1835669726791393365#m',
#    'text': '¡𝗟𝗔 𝗙𝗩𝗙 𝗣𝗨𝗝𝗔 𝗣𝗢𝗥 𝗠𝗔𝗟𝗗𝗜𝗡𝗜! • 🚨🍝🇻🇪  Informa @NicoSchira vía X que la @FVF_Oficial mantiene la intención de repatriar al menor de la dinastía Maldini.   Sin embargo, el MC del Monza de Italia, quien ya manifestó su interés en defender a la “azzurri”, está siendo monitoreado por Luciano Spalletti y podría ser convocado por la selección Europea en la próxima UEFA Nations League.   ¿Su vínculo con Venezuela? Es hijo de Adriana Fossa, ex modelo venezolana y esposa de Paolo Maldini.   La FVF ha ‘repatriado’ en el último tiempo a jugadores como Daniele Quieto, Lorenzo D’Agostini y Alessandro Milani, todos nacidos en Italia. ¿Lo lograrán con el hijo del mítico ex defensor italiano?  #Vinotinto #Maldini #Italia #SoloVenex',
#    'user': {'name': 'SOLOVENEX',
#     'username': '@SOLOVENEX_',
#     'profile_id': '1812834507617124352',
#     'avatar': 'https://pbs.twimg.com/profile_images/1812834507617124352/nSbyIO4J_bigger.jpg'},
#    'date': 'Sep 16, 2024 · 1:19 PM UTC',
#    'is-retweet': True,
#    'is-pinned': False,
#    'external-link': '',
#    'replying-to': [],
#    'quoted-post': {},
#    'stats': {'comments': 42, 'retweets': 14, 'quotes': 7, 'likes': 155},
#    'pictures': ['https://pbs.twimg.com/media/GXmb4VdWkAAST8P.jpg'],
#    'videos': [],
#    'gifs': []},
#   {'link': 'https://twitter.com/SOLOVENEX_/status/1835741646035845318#m',
#    'text': '¿El 𝗥𝗘𝗬 de 𝗔𝗧𝗟𝗔𝗡𝗧𝗔?  ¡Sigue siendo 𝗩𝗜𝗡𝗢𝗧𝗜𝗡𝗧𝗢! • 😎👑🇻🇪  #VenEx #MLS #MLB #SoloVenex   | 📸 @ATLUTD |',
#    'user': {'name': 'SOLOVENEX',
#     'username': '@SOLOVENEX_',
#     'profile_id': '1812834507617124352',
#     'avatar': 'https://pbs.twimg.com/profile_images/1812834507617124352/nSbyIO4J_bigger.jpg'},
#    'date': 'Sep 16, 2024 · 6:04 PM UTC',
#    'is-retweet': False,
#    'is-pinned': False,
#    'external-link': '',
#    'replying-to': [],
#    'quoted-post': {},
#    'stats': {'comments': 2, 'retweets': 0, 'quotes': 0, 'likes': 3},
#    'pictures': ['https://pbs.twimg.com/media/GXndSiyXEAA_apx.jpg'],
#    'videos': [],
#    'gifs': []},
#   {'link': 'https://twitter.com/SOLOVENEX_/status/1835739583797133389#m',
#    'text': '𝗗𝗔𝗡𝗜 𝗡𝗜𝗘𝗧𝗢 (@91nietodani): el único jugador español de la Liga FUTVE 1 y 2. Este domingo jugó su segundo partido en Venezuela con el @Anzoategui_FC. ⚽️🇻🇪  El elenco oriental igualó 0-0 con @dynamopuertofc dejando ‘flashes’ técnicos del buen volante europeo.   En España, pasó por la filial del FC Barcelona, jugó en el Numancia, Éibar, y además presume un paso por el Independiente del Valle en suelo ecuatoriano.   #FutVe #Anzoátegui #SoloVenex   | 📸 Imágenes de apoyo: @renatophotos |',
#    'user': {'name': 'SOLOVENEX',
#     'username': '@SOLOVENEX_',
#     'profile_id': '1812834507617124352',
#     'avatar': 'https://pbs.twimg.com/profile_images/1812834507617124352/nSbyIO4J_bigger.jpg'},
#    'date': 'Sep 16, 2024 · 5:56 PM UTC',
#    'is-retweet': False,
#    'is-pinned': False,
#    'external-link': '',
#    'replying-to': [],
#    'quoted-post': {},
#    'stats': {'comments': 0, 'retweets': 4, 'quotes': 0, 'likes': 19},
#    'pictures': [],
#    'videos': ['https://video.twimg.com/amplify_video/1835739392788353024/pl/-RdlFAPq4iA2sASX.m3u8?tag=16&v=c01'],
#    'gifs': []},
#   {'link': 'https://twitter.com/carlostaracher/status/1835712436382355852#m',
#    'text': 'El mediocampista José Correa (2006) se encuentra en Europa, definiendo su futuro. En la postal, entrena de la mano de la academia FDC Vista, de Krasnodar.   No está solo, lo acompaña Juan Campos, el delantero clase 2007 que también es ficha del @NuevaEsparta_FC.  .@SOLOVENEX_ 🇻🇪',
#    'user': {'name': 'Carlos Tarache',
#     'username': '@carlostaracher',
#     'profile_id': '1826421340812791808',
#     'avatar': 'https://pbs.twimg.com/profile_images/1826421340812791808/xtKkoBMm_bigger.jpg'},
#    'date': 'Sep 16, 2024 · 4:08 PM UTC',
#    'is-retweet': True,
#    'is-pinned': False,
#    'external-link': '',
#    'replying-to': [],
#    'quoted-post': {},
#    'stats': {'comments': 3, 'retweets': 9, 'quotes': 1, 'likes': 109},
#    'pictures': ['https://pbs.twimg.com/media/GXnCuaIXYAECMnw.jpg'],
#    'videos': [],
#    'gifs': []},
#   {'link': 'https://twitter.com/SOLOVENEX_/status/1835471906004181304#m',
#    'text': '📱 • Síguelos en Instagram:  https://www.instagram.com/xednysport?igsh=eXR4OWwxZTU0c2V1',
#    'user': {'name': 'SOLOVENEX',
#     'username': '@SOLOVENEX_',
#     'profile_id': '1812834507617124352',
#     'avatar': 'https://pbs.twimg.com/profile_images/1812834507617124352/nSbyIO4J_bigger.jpg'},
#    'date': 'Sep 16, 2024 · 12:12 AM UTC',
#    'is-retweet': False,
#    'is-pinned': False,
#    'external-link': '',
#    'replying-to': [],
#    'quoted-post': {},
#    'stats': {'comments': 0, 'retweets': 0, 'quotes': 0, 'likes': 0},
#    'pictures': [],
#    'videos': [],
#    'gifs': []},
#   {'link': 'https://twitter.com/SOLOVENEX_/status/1835471756535980348#m',
#    'text': '¡Xedny Sport 𝗦𝗜𝗘𝗠𝗣𝗥𝗘 nos acompaña! 🇻🇪  Nuestros aliados engalanaron las instalaciones del Monumental de Maturín con sus  prendas.   Xedny es patrocinante oficial de SOLOVENEX en el camino al Mundial - 2026. ¡Cree en ti!  #PoderVinotinto',
#    'user': {'name': 'SOLOVENEX',
#     'username': '@SOLOVENEX_',
#     'profile_id': '1812834507617124352',
#     'avatar': 'https://pbs.twimg.com/profile_images/1812834507617124352/nSbyIO4J_bigger.jpg'},
#    'date': 'Sep 16, 2024 · 12:12 AM UTC',
#    'is-retweet': False,
#    'is-pinned': False,
#    'external-link': '',
#    'replying-to': [],
#    'quoted-post': {},
#    'stats': {'comments': 1, 'retweets': 0, 'quotes': 0, 'likes': 2},
#    'pictures': ['https://pbs.twimg.com/media/GXjnw2tWQAALd_W.jpg'],
#    'videos': [],
#    'gifs': []},
#   {'link': 'https://twitter.com/SOLOVENEX_/status/1835345893215637991#m',
#    'text': '¡𝗧𝗘 𝗟𝗟𝗘𝗩𝗔𝗠𝗢𝗦 𝗔𝗟 🇻🇪 #𝗩𝗘𝗡 - #𝗔𝗥𝗚 🇦🇷!  • Junto a la @miradeltigre gestionamos tu viaje a Maturín para apoyar a la @selevinotinto en las Eliminatorias CONMEBOL con ¡𝗧𝗢𝗗𝗢! incluido.   ¿Próximo rival? ¡𝗟𝗮 𝗰𝗮𝗺𝗽𝗲𝗼𝗻𝗮 𝗱𝗲𝗹 𝗺𝘂𝗻𝗱𝗼!  🎟️ @SOLOVENEX_ es vendedor autorizado de los mejores paquetes de viaje aéreos y terrestres para una cita que será especial. ¿Ustedes están listos?  📥 • Consulta por nuestros planes o comenta este post con la etiqueta (HT) #VenezuelaVsArgentina   Te atendemos al +58-414-810-59-69   Ven y se parte del #𝗣𝗼𝗱𝗲𝗿𝗩𝗶𝗻𝗼𝘁𝗶𝗻𝘁𝗼 🇻🇪',
#    'user': {'name': 'SOLOVENEX',
#     'username': '@SOLOVENEX_',
#     'profile_id': '1812834507617124352',
#     'avatar': 'https://pbs.twimg.com/profile_images/1812834507617124352/nSbyIO4J_bigger.jpg'},
#    'date': 'Sep 15, 2024 · 3:52 PM UTC',
#    'is-retweet': True,
#    'is-pinned': False,
#    'external-link': '',
#    'replying-to': [],
#    'quoted-post': {},
#    'stats': {'comments': 1, 'retweets': 2, 'quotes': 0, 'likes': 8},
#    'pictures': ['https://pbs.twimg.com/media/GXh1WvPWoAELuXd.jpg',
#     'https://pbs.twimg.com/media/GXh1WvVXkAAxnBX.jpg'],
#    'videos': [],
#    'gifs': []},
#   {'link': 'https://twitter.com/SOLOVENEX_/status/1835093710046216334#m',
#    'text': '‘𝑽𝑰𝑵𝑰’ 𝙭 𝑱𝑶𝑵 = 🇧🇷🫱🏿\u200d🫲🏻🇻🇪  El saludo entre el crack brasileño y el venezolano de la @RealSociedad tras medir fuerzas en #LaLiga.   Aramburu jugó completo en la caída de la Real Sociedad 0-2 ante el Real Madrid y cometió un penal. ¿Cómo valoras el partido del defensor? ⬇️  #VenEx #LaLiga #Viral #SoloVenex   | 🎥 Vía: @marca |',
#    'user': {'name': 'SOLOVENEX',
#     'username': '@SOLOVENEX_',
#     'profile_id': '1812834507617124352',
#     'avatar': 'https://pbs.twimg.com/profile_images/1812834507617124352/nSbyIO4J_bigger.jpg'},
#    'date': 'Sep 14, 2024 · 11:10 PM UTC',
#    'is-retweet': False,
#    'is-pinned': False,
#    'external-link': '',
#    'replying-to': [],
#    'quoted-post': {},
#    'stats': {'comments': 3, 'retweets': 5, 'quotes': 0, 'likes': 29},
#    'pictures': [],
#    'videos': ['https://video.twimg.com/amplify_video/1835093617418948608/pl/QRKvBpRUq5DrPu-v.m3u8?tag=16'],
#    'gifs': []},
#   {'link': 'https://twitter.com/SOLOVENEX_/status/1835042879821300176#m',
#    'text': 'Con Aramburu 𝙉𝙊, #Mbappe • 🥷🚫🇻🇪',
#    'user': {'name': 'SOLOVENEX',
#     'username': '@SOLOVENEX_',
#     'profile_id': '1812834507617124352',
#     'avatar': 'https://pbs.twimg.com/profile_images/1812834507617124352/nSbyIO4J_bigger.jpg'},
#    'date': 'Sep 14, 2024 · 7:48 PM UTC',
#    'is-retweet': False,
#    'is-pinned': False,
#    'external-link': '',
#    'replying-to': [],
#    'quoted-post': {},
#    'stats': {'comments': 79, 'retweets': 353, 'quotes': 46, 'likes': 2063},
#    'pictures': [],
#    'videos': ['https://video.twimg.com/amplify_video/1835042703584739328/pl/MTTQ-Z2rBCd4GElD.m3u8?tag=16&v=e5b'],
#    'gifs': []},
#   {'link': 'https://twitter.com/SOLOVENEX_/status/1835021064482459913#m',
#    'text': '.@JonAramburu3 𝙏𝙄𝙏𝙐𝙇𝘼𝙍 ante el 𝙈𝘼𝘿𝙍𝙄𝘿. 🚨🇻🇪',
#    'user': {'name': 'SOLOVENEX',
#     'username': '@SOLOVENEX_',
#     'profile_id': '1812834507617124352',
#     'avatar': 'https://pbs.twimg.com/profile_images/1812834507617124352/nSbyIO4J_bigger.jpg'},
#    'date': 'Sep 14, 2024 · 6:21 PM UTC',
#    'is-retweet': False,
#    'is-pinned': False,
#    'external-link': '',
#    'replying-to': [],
#    'quoted-post': {'link': 'https://twitter.com/RealSociedad/status/1835018265963143265#m',
#     'text': '📋 ¡La 𝗔𝗟𝗜𝗡𝗘𝗔𝗖𝗜𝗢́𝗡 de la Real 🆚 @RealMadrid!  #RealSociedadRealMadrid',
#     'user': {'name': 'Real Sociedad Fútbol',
#      'username': '@RealSociedad',
#      'profile_id': '1806965321032519680',
#      'avatar': 'https://pbs.twimg.com/profile_images/1806965321032519680/upcVcCAo_mini.jpg'},
#     'date': 'Sep 14, 2024 · 6:10 PM UTC',
#     'pictures': ['https://pbs.twimg.com/media/GXdJBrGXsAAQY5z.jpg',
#      'https://pbs.twimg.com/media/GXdJBrVXwAAlLoi.jpg'],
#     'videos': [],
#     'gifs': []},
#    'stats': {'comments': 0, 'retweets': 0, 'quotes': 0, 'likes': 5},
#    'pictures': [],
#    'videos': [],
#    'gifs': []},
#   {'link': 'https://twitter.com/SOLOVENEX_/status/1835019774239109256#m',
#    'text': '#VenEx | #Talento | Carlos Rojas, un ‘obelisco’ venezolano en Norteamérica: https://solovenex.com/carlos-rojas-un-obelisco-venezolano-en-norteamerica/',
#    'user': {'name': 'SOLOVENEX',
#     'username': '@SOLOVENEX_',
#     'profile_id': '1812834507617124352',
#     'avatar': 'https://pbs.twimg.com/profile_images/1812834507617124352/nSbyIO4J_bigger.jpg'},
#    'date': 'Sep 14, 2024 · 6:16 PM UTC',
#    'is-retweet': False,
#    'is-pinned': False,
#    'external-link': '',
#    'replying-to': [],
#    'quoted-post': {},
#    'stats': {'comments': 0, 'retweets': 1, 'quotes': 0, 'likes': 2},
#    'pictures': [],
#    'videos': [],
#    'gifs': []},
#   {'link': 'https://twitter.com/SOLOVENEX_/status/1834964004374020433#m',
#    'text': '| 🎥 Vía: @RealSociedad |',
#    'user': {'name': 'SOLOVENEX',
#     'username': '@SOLOVENEX_',
#     'profile_id': '1812834507617124352',
#     'avatar': 'https://pbs.twimg.com/profile_images/1812834507617124352/nSbyIO4J_bigger.jpg'},
#    'date': 'Sep 14, 2024 · 2:34 PM UTC',
#    'is-retweet': False,
#    'is-pinned': False,
#    'external-link': '',
#    'replying-to': [],
#    'quoted-post': {},
#    'stats': {'comments': 0, 'retweets': 0, 'quotes': 0, 'likes': 0},
#    'pictures': [],
#    'videos': [],
#    'gifs': []},
#   {'link': 'https://twitter.com/SOLOVENEX_/status/1834963942327701897#m',
#    'text': '.@JonAramburu3, cumpliendo el sueño. (😎)',
#    'user': {'name': 'SOLOVENEX',
#     'username': '@SOLOVENEX_',
#     'profile_id': '1812834507617124352',
#     'avatar': 'https://pbs.twimg.com/profile_images/1812834507617124352/nSbyIO4J_bigger.jpg'},
#    'date': 'Sep 14, 2024 · 2:34 PM UTC',
#    'is-retweet': False,
#    'is-pinned': False,
#    'external-link': '',
#    'replying-to': [],
#    'quoted-post': {},
#    'stats': {'comments': 1, 'retweets': 5, 'quotes': 0, 'likes': 52},
#    'pictures': [],
#    'videos': ['https://video.twimg.com/amplify_video/1834963724462936064/pl/Gu7Okwwa3nBAI-uw.m3u8?tag=16'],
#    'gifs': []},
#   {'link': 'https://twitter.com/SOLOVENEX_/status/1834936449461878857#m',
#    'text': '“𝒀𝒐 𝒔𝒊𝒆𝒎𝒑𝒓𝒆 𝒆𝒍𝒆𝒈𝒊𝒓𝒊́𝒂 𝒂𝒍 𝑪𝒂𝒓𝒂𝒄𝒂𝒔” 🇾🇪  🔹 @juanpianor1 es nuevo jugador del #CFC.  Añor vivirá su tercer ciclo como jugador del @Caracas_FC tras su paso por el Panetolikos griego.   El volante 10 de perfil zurdo se reencuentra con Fernando Aristeguieta y fue convocado para el partido de este sábado ante Angostura.  Añor portará el dorsal ‘08’ en su regreso al ‘Rojo’.  #FutVe #CFC #Fichajes #SoloVenex',
#    'user': {'name': 'SOLOVENEX',
#     'username': '@SOLOVENEX_',
#     'profile_id': '1812834507617124352',
#     'avatar': 'https://pbs.twimg.com/profile_images/1812834507617124352/nSbyIO4J_bigger.jpg'},
#    'date': 'Sep 14, 2024 · 12:45 PM UTC',
#    'is-retweet': False,
#    'is-pinned': False,
#    'external-link': '',
#    'replying-to': [],
#    'quoted-post': {},
#    'stats': {'comments': 0, 'retweets': 1, 'quotes': 0, 'likes': 26},
#    'pictures': ['https://pbs.twimg.com/media/GXcAuBtWoAA9xQN.jpg'],
#    'videos': [],
#    'gifs': []},
#   {'link': 'https://twitter.com/SOLOVENEX_/status/1834697033984491984#m',
#    'text': '¿El ‘𝗕𝗨́𝗙𝗔𝗟𝗢’ retará al 𝗠𝗔𝗗𝗥𝗜𝗗? • 😳❗️  Se jugará la jornada la fecha 05 de LaLiga y Jon Aramburu parte en la lista de convocados para el partido entre la Real Sociedad y el Real Madrid.   El lateral derecho, quien viene ser incluido en el XI Ideal de las jornadas 07 y 08 de las Eliminatorias, podría ser titular ante el combinado ‘merengue’.   Vívelo y 𝗚𝗔𝗡𝗔 junto a @ParleyEnLinea con los mejores logros del mercado.  ¡𝗙𝗮́𝗰𝗶𝗹, 𝗿𝗮́𝗽𝗶𝗱𝗼 𝘆 𝘀𝗲𝗴𝘂𝗿𝗼! • 🏦⚽️🇻🇪  #VenEx #LaLiga #Aramburu #SoloVenex',
#    'user': {'name': 'SOLOVENEX',
#     'username': '@SOLOVENEX_',
#     'profile_id': '1812834507617124352',
#     'avatar': 'https://pbs.twimg.com/profile_images/1812834507617124352/nSbyIO4J_bigger.jpg'},
#    'date': 'Sep 13, 2024 · 8:53 PM UTC',
#    'is-retweet': False,
#    'is-pinned': False,
#    'external-link': '',
#    'replying-to': [],
#    'quoted-post': {},
#    'stats': {'comments': 0, 'retweets': 0, 'quotes': 0, 'likes': 6},
#    'pictures': ['https://pbs.twimg.com/media/GXYnOCNXMAAypB6.jpg'],
#    'videos': [],
#    'gifs': []},
#   {'link': 'https://twitter.com/SOLOVENEX_/status/1834641418255503805#m',
#    'text': '🇻🇪 𝗖𝗔𝗥𝗟𝗢𝗦 𝗝𝗘𝗦𝗨́𝗦 𝗥𝗢𝗝𝗔𝗦 (𝟮𝟬𝟬𝟲) es otro de los jóvenes talentos que pisa firme bajo la estructura del fútbol formativo estadounidense. Este, de la mano de la University Central of Florida, donde se desarrolla tras tener un gran desempeño en las inferioes del Orlando City y el Florida Kraze Krush.   Carlos Jesús, delantero centro de amplia proyección, es hermano de Juan Rojas (2008), el guardameta venezolano que entrenó con la selección de Brasil en su último ciclo de preparación previo a la Copa América y 𝘃𝗶𝗲𝗻𝗲 𝗱𝗲 𝗮𝗻𝗼𝘁𝗮𝗿 𝗱𝗼𝘀 𝗴𝗼𝗹𝗲𝘀 𝘆 𝗿𝗲𝗽𝗮𝗿𝘁𝗶𝗿 𝘂𝗻𝗮 𝗮𝘀𝗶𝘀𝘁𝗲𝗻𝗰𝗶𝗮 en su debut oficial en la NCAA con la UCF.  Atacante de juego aéreo dominante gracias a sus 2.01 MTS de altura y una notable capacidad de espaldas al arco y definición. Nacido en Valencia, y es pieza elegible para la selección nacional U20.  #VenEx #Rojas #Scouting #SoloVenex',
#    'user': {'name': 'SOLOVENEX',
#     'username': '@SOLOVENEX_',
#     'profile_id': '1812834507617124352',
#     'avatar': 'https://pbs.twimg.com/profile_images/1812834507617124352/nSbyIO4J_bigger.jpg'},
#    'date': 'Sep 13, 2024 · 5:12 PM UTC',
#    'is-retweet': False,
#    'is-pinned': False,
#    'external-link': '',
#    'replying-to': [],
#    'quoted-post': {},
#    'stats': {'comments': 0, 'retweets': 1, 'quotes': 0, 'likes': 11},
#    'pictures': ['https://pbs.twimg.com/media/GXX0o70WUAAY_ph.jpg',
#     'https://pbs.twimg.com/media/GXX0o7wXkAAdhJn.jpg'],
#    'videos': [],
#    'gifs': []},
#   {'link': 'https://twitter.com/SOLOVENEX_/status/1834349489802395743#m',
#    'text': '“𝗟𝗢𝗖𝗢𝗦” por el juego. (⚽️🤓)   La camaradería entre Bielsa y Batista en el pre.  #EliminatoriasSudamericanas',
#    'user': {'name': 'SOLOVENEX',
#     'username': '@SOLOVENEX_',
#     'profile_id': '1812834507617124352',
#     'avatar': 'https://pbs.twimg.com/profile_images/1812834507617124352/nSbyIO4J_bigger.jpg'},
#    'date': 'Sep 12, 2024 · 9:52 PM UTC',
#    'is-retweet': False,
#    'is-pinned': False,
#    'external-link': '',
#    'replying-to': [],
#    'quoted-post': {},
#    'stats': {'comments': 0, 'retweets': 0, 'quotes': 0, 'likes': 3},
#    'pictures': ['https://pbs.twimg.com/media/GXTrC3_XwAAyceh.jpg',
#     'https://pbs.twimg.com/media/GXTrC3_W4AAkYNJ.jpg'],
#    'videos': [],
#    'gifs': []},
#   {'link': 'https://twitter.com/SOLOVENEX_/status/1834305236988498227#m',
#    'text': '𝗢𝗙𝗜𝗖𝗜𝗔𝗟 | ¡Guarirapa se va al 𝐂𝐒𝐊𝐀! 🔴  • Llegó 𝗖𝗘𝗗𝗜𝗗𝗢 por un año desde el Sochi.  * Opción a compra por el equipo que hace vida en la máxima categoría del fútbol ruso.   #VenEx #Fichajes #News #SoloVenex',
#    'user': {'name': 'SOLOVENEX',
#     'username': '@SOLOVENEX_',
#     'profile_id': '1812834507617124352',
#     'avatar': 'https://pbs.twimg.com/profile_images/1812834507617124352/nSbyIO4J_bigger.jpg'},
#    'date': 'Sep 12, 2024 · 6:57 PM UTC',
#    'is-retweet': False,
#    'is-pinned': False,
#    'external-link': '',
#    'replying-to': [],
#    'quoted-post': {},
#    'stats': {'comments': 0, 'retweets': 5, 'quotes': 1, 'likes': 37},
#    'pictures': ['https://pbs.twimg.com/media/GXTC4rDXYAASWrb.jpg'],
#    'videos': [],
#    'gifs': []},
#   {'link': 'https://twitter.com/SOLOVENEX_/status/1834272145628954684#m',
#    'text': 'Durante la estadía en Maturín nuestro director @carlostaracher sostuvo una nutritiva charla con parte del tren directivo de @LaPizarraDelDT con el fin de seguir fortaleciendo alianzas en pro del crecimiento del fútbol venezolano.  Continuaremos trabajando de la mano de los mejores con el objetivo de seguir contribuyendo a la evolución del fútbol en nuestro país.  @LaPizarraDelDT 🤝🏻 @SOLOVENEX_',
#    'user': {'name': 'SOLOVENEX',
#     'username': '@SOLOVENEX_',
#     'profile_id': '1812834507617124352',
#     'avatar': 'https://pbs.twimg.com/profile_images/1812834507617124352/nSbyIO4J_bigger.jpg'},
#    'date': 'Sep 12, 2024 · 4:45 PM UTC',
#    'is-retweet': False,
#    'is-pinned': False,
#    'external-link': '',
#    'replying-to': [],
#    'quoted-post': {},
#    'stats': {'comments': 0, 'retweets': 1, 'quotes': 1, 'likes': 4},
#    'pictures': ['https://pbs.twimg.com/media/GXSkI4aW8AA3nuQ.jpg'],
#    'videos': [],
#    'gifs': []},
#   {'link': 'https://twitter.com/SOLOVENEX_/status/1834229309579428033#m',
#    'text': '𝗢𝗙𝗜𝗖𝗜𝗔𝗟 | 𝗗𝗘𝗜𝗩𝗜𝗗 𝗧𝗘𝗚𝗨𝗘𝗦 (𝟮𝟬𝟬𝟰) firmó por cuatro años con el @pfcsochi de la segunda división de Rusia, que lo cedió por un año con opción a compra al Chernomorets de la misma categoría.   El atacante llegó en calidad de agente libre tras su paso por el Deportivo Táchira de la Liga FUTVE.   Información adelantada por @CLMerlo.  #VenEx #Fichajes #Tegues #SoloVenex',
#    'user': {'name': 'SOLOVENEX',
#     'username': '@SOLOVENEX_',
#     'profile_id': '1812834507617124352',
#     'avatar': 'https://pbs.twimg.com/profile_images/1812834507617124352/nSbyIO4J_bigger.jpg'},
#    'date': 'Sep 12, 2024 · 1:55 PM UTC',
#    'is-retweet': False,
#    'is-pinned': False,
#    'external-link': '',
#    'replying-to': [],
#    'quoted-post': {},
#    'stats': {'comments': 0, 'retweets': 0, 'quotes': 0, 'likes': 0},
#    'pictures': ['https://pbs.twimg.com/media/GXR91F9XsAAf6Q_.jpg'],
#    'videos': [],
#    'gifs': []},
#   {'link': 'https://twitter.com/SOLOVENEX_/status/1833864180580946201#m',
#    'text': '🪑',
#    'user': {'name': 'SOLOVENEX',
#     'username': '@SOLOVENEX_',
#     'profile_id': '1812834507617124352',
#     'avatar': 'https://pbs.twimg.com/profile_images/1812834507617124352/nSbyIO4J_bigger.jpg'},
#    'date': 'Sep 11, 2024 · 1:44 PM UTC',
#    'is-retweet': False,
#    'is-pinned': False,
#    'external-link': '',
#    'replying-to': [],
#    'quoted-post': {},
#    'stats': {'comments': 0, 'retweets': 0, 'quotes': 0, 'likes': 14},
#    'pictures': ['https://pbs.twimg.com/media/GXMxvimXsAAxkc6.jpg'],
#    'videos': [],
#    'gifs': []},
#   {'link': 'https://twitter.com/SOLOVENEX_/status/1833858644770766876#m',
#    'text': '| 📸 @PonceRance |',
#    'user': {'name': 'SOLOVENEX',
#     'username': '@SOLOVENEX_',
#     'profile_id': '1812834507617124352',
#     'avatar': 'https://pbs.twimg.com/profile_images/1812834507617124352/nSbyIO4J_bigger.jpg'},
#    'date': 'Sep 11, 2024 · 1:22 PM UTC',
#    'is-retweet': False,
#    'is-pinned': False,
#    'external-link': '',
#    'replying-to': [],
#    'quoted-post': {},
#    'stats': {'comments': 0, 'retweets': 0, 'quotes': 0, 'likes': 1},
#    'pictures': [],
#    'videos': [],
#    'gifs': []},
#   {'link': 'https://twitter.com/SOLOVENEX_/status/1833858073938591815#m',
#    'text': '𝑭𝒓𝒆𝒏𝒕𝒆 𝒆𝒏 𝒂𝒍𝒕𝒐, 𝑽𝒆𝒏𝒆𝒛𝒖𝒆𝒍𝒂 🇻🇪',
#    'user': {'name': 'SOLOVENEX',
#     'username': '@SOLOVENEX_',
#     'profile_id': '1812834507617124352',
#     'avatar': 'https://pbs.twimg.com/profile_images/1812834507617124352/nSbyIO4J_bigger.jpg'},
#    'date': 'Sep 11, 2024 · 1:20 PM UTC',
#    'is-retweet': False,
#    'is-pinned': False,
#    'external-link': '',
#    'replying-to': [],
#    'quoted-post': {},
#    'stats': {'comments': 2, 'retweets': 0, 'quotes': 0, 'likes': 12},
#    'pictures': ['https://pbs.twimg.com/media/GXMsMIaXoAA6ZC9.jpg',
#     'https://pbs.twimg.com/media/GXMsMIeXkAA2lxE.jpg'],
#    'videos': [],
#    'gifs': []},
#   {'link': 'https://twitter.com/SOLOVENEX_/status/1833718780196753852#m',
#    'text': '¡Venezuela 𝗡𝗢 pudo con Uruguay!   📸 • Algunas de las postales que dejó el empate 0-0 entre venezolanos y “charrúas” en el Monumental.   Venezuela cierra la doble fecha de septiembre en la sexta casilla con 10 puntos tras la caída ante Bolivia.  #Vinotinto #Eliminatorias #SoloVenex   | 📸 @PonceRance',
#    'user': {'name': 'SOLOVENEX',
#     'username': '@SOLOVENEX_',
#     'profile_id': '1812834507617124352',
#     'avatar': 'https://pbs.twimg.com/profile_images/1812834507617124352/nSbyIO4J_bigger.jpg'},
#    'date': 'Sep 11, 2024 · 4:06 AM UTC',
#    'is-retweet': False,
#    'is-pinned': False,
#    'external-link': '',
#    'replying-to': [],
#    'quoted-post': {},
#    'stats': {'comments': 3, 'retweets': 1, 'quotes': 0, 'likes': 6},
#    'pictures': ['https://pbs.twimg.com/media/GXKtc6iWkAARjRj.jpg',
#     'https://pbs.twimg.com/media/GXKtc6oX0AAZP2c.jpg',
#     'https://pbs.twimg.com/media/GXKtc6uXoAAxefH.jpg',
#     'https://pbs.twimg.com/media/GXKtc6vXkAAAHAM.jpg'],
#    'videos': [],
#    'gifs': []},
#   {'link': 'https://twitter.com/SOLOVENEX_/status/1833713059828744465#m',
#    'text': '🇻🇪🎙️• #𝗟𝗮𝗭𝗼𝗻𝗮𝗠𝗶𝘅𝘁𝗮 | #𝗦𝗼𝗹𝗼𝗩𝗲𝗻𝗲𝘅:   Jon Aramburu y sus sensaciones tras el 0-0 con Uruguay por la jornada 08 de las Eliminatorias.   Gana junto a @ParleyEnLinea con los mejores logros del mercado. ¡𝗙𝗮́𝗰𝗶𝗹, 𝗿𝗮́𝗽𝗶𝗱𝗼 𝘆 𝘀𝗲𝗴𝘂𝗿𝗼!  #Vinotinto #Viral #Aramburu #SoloVenex',
#    'user': {'name': 'SOLOVENEX',
#     'username': '@SOLOVENEX_',
#     'profile_id': '1812834507617124352',
#     'avatar': 'https://pbs.twimg.com/profile_images/1812834507617124352/nSbyIO4J_bigger.jpg'},
#    'date': 'Sep 11, 2024 · 3:43 AM UTC',
#    'is-retweet': False,
#    'is-pinned': False,
#    'external-link': '',
#    'replying-to': [],
#    'quoted-post': {},
#    'stats': {'comments': 0, 'retweets': 7, 'quotes': 2, 'likes': 63},
#    'pictures': [],
#    'videos': ['https://video.twimg.com/amplify_video/1833712723038793728/pl/sKHPw_HSNJ6r5Lzs.m3u8?tag=16&v=02d'],
#    'gifs': []},
#   {'link': 'https://twitter.com/SOLOVENEX_/status/1833570127192985742#m',
#    'text': '.@carlostaracher fue por una cachapita en Maturín y se consiguió con #Soteldo. 😂🫓',
#    'user': {'name': 'SOLOVENEX',
#     'username': '@SOLOVENEX_',
#     'profile_id': '1812834507617124352',
#     'avatar': 'https://pbs.twimg.com/profile_images/1812834507617124352/nSbyIO4J_bigger.jpg'},
#    'date': 'Sep 10, 2024 · 6:15 PM UTC',
#    'is-retweet': False,
#    'is-pinned': False,
#    'external-link': '',
#    'replying-to': [],
#    'quoted-post': {},
#    'stats': {'comments': 1, 'retweets': 11, 'quotes': 0, 'likes': 109},
#    'pictures': [],
#    'videos': ['https://video.twimg.com/amplify_video/1833569765106843648/pl/8GSq7FxEvFrTFEWd.m3u8?tag=16&v=d04'],
#    'gifs': []},
#   {'link': 'https://twitter.com/SOLOVENEX_/status/1833546490956157160#m',
#    'text': '𝗠𝗔𝗡𝗢, 𝗧𝗜𝗘𝗡𝗘𝗡 𝗙𝗘 • 😎🇻🇪🔥  Y también lo viven con @ParleyEnLinea.   WWW.PARLEY.COM',
#    'user': {'name': 'SOLOVENEX',
#     'username': '@SOLOVENEX_',
#     'profile_id': '1812834507617124352',
#     'avatar': 'https://pbs.twimg.com/profile_images/1812834507617124352/nSbyIO4J_bigger.jpg'},
#    'date': 'Sep 10, 2024 · 4:42 PM UTC',
#    'is-retweet': False,
#    'is-pinned': False,
#    'external-link': '',
#    'replying-to': [],
#    'quoted-post': {},
#    'stats': {'comments': 0, 'retweets': 1, 'quotes': 0, 'likes': 2},
#    'pictures': [],
#    'videos': ['https://video.twimg.com/amplify_video/1833546425726078976/pl/dD1wdyDIbh-S9uQj.m3u8?tag=16'],
#    'gifs': []},
#   {'link': 'https://twitter.com/SOLOVENEX_/status/1833530032989606304#m',
#    'text': 'Resumen del video: SOTERDO 😎',
#    'user': {'name': 'SOLOVENEX',
#     'username': '@SOLOVENEX_',
#     'profile_id': '1812834507617124352',
#     'avatar': 'https://pbs.twimg.com/profile_images/1812834507617124352/nSbyIO4J_bigger.jpg'},
#    'date': 'Sep 10, 2024 · 3:36 PM UTC',
#    'is-retweet': False,
#    'is-pinned': False,
#    'external-link': '',
#    'replying-to': [],
#    'quoted-post': {},
#    'stats': {'comments': 0, 'retweets': 0, 'quotes': 0, 'likes': 2},
#    'pictures': [],
#    'videos': [],
#    'gifs': []},
#   {'link': 'https://twitter.com/SOLOVENEX_/status/1833529336139530419#m',
#    'text': '¡Hay ambiente en Maturín! | 😂👕🇻🇪  Seguimos recorriendo las calles de la Ciudad Distinta. Y miren que es distinta…  .@RMsportshop: “vestimos tu pasión”.  #Vinotinto #Venezuela #Soterdo #SoloVenex',
#    'user': {'name': 'SOLOVENEX',
#     'username': '@SOLOVENEX_',
#     'profile_id': '1812834507617124352',
#     'avatar': 'https://pbs.twimg.com/profile_images/1812834507617124352/nSbyIO4J_bigger.jpg'},
#    'date': 'Sep 10, 2024 · 3:33 PM UTC',
#    'is-retweet': False,
#    'is-pinned': False,
#    'external-link': '',
#    'replying-to': [],
#    'quoted-post': {},
#    'stats': {'comments': 2, 'retweets': 8, 'quotes': 2, 'likes': 88},
#    'pictures': [],
#    'videos': ['https://video.twimg.com/amplify_video/1833528052728336384/pl/1k9rxH8AwQ4DsOo2.m3u8?tag=16&v=26a'],
#    'gifs': []},
#   {'link': 'https://twitter.com/SOLOVENEX_/status/1833512752632987816#m',
#    'text': '¿Qué le dirías a Fernando “Bocha” Batista a horas del partido ante Uruguay? • 💭🇻🇪  #EliminatoriasSudamericanas',
#    'user': {'name': 'SOLOVENEX',
#     'username': '@SOLOVENEX_',
#     'profile_id': '1812834507617124352',
#     'avatar': 'https://pbs.twimg.com/profile_images/1812834507617124352/nSbyIO4J_bigger.jpg'},
#    'date': 'Sep 10, 2024 · 2:27 PM UTC',
#    'is-retweet': False,
#    'is-pinned': False,
#    'external-link': '',
#    'replying-to': [],
#    'quoted-post': {},
#    'stats': {'comments': 0, 'retweets': 0, 'quotes': 0, 'likes': 2},
#    'pictures': ['https://pbs.twimg.com/media/GXHyH69WIAAZqSe.jpg',
#     'https://pbs.twimg.com/media/GXHyH67WkAAmuV4.jpg'],
#    'videos': [],
#    'gifs': []},
#   {'link': 'https://twitter.com/SOLOVENEX_/status/1833307176594526538#m',
#    'text': '| 📸 @PonceRance |',
#    'user': {'name': 'SOLOVENEX',
#     'username': '@SOLOVENEX_',
#     'profile_id': '1812834507617124352',
#     'avatar': 'https://pbs.twimg.com/profile_images/1812834507617124352/nSbyIO4J_bigger.jpg'},
# ...
#    'gifs': []},
#   {'link': 'https://twitter.com/SOLOVENEX_/status/1798697787346800998#m',
#    'text': 'En su visita a Venezuela, Yangel Herrera pasó por la Escuela Mejía, del estado Monagas. Recordada por ser la primera que vio sus primeros pases con pelota al pie. Donde el sueño comenzó. Así rompió en llanto el mediocampista vinotinto en medio de un discurso a las nuevas generaciones. El ejemplo de @YangelHerrera8. ¡𝗡𝗨𝗡𝗖𝗔 𝗢𝗟𝗩𝗜𝗗𝗘𝗦 𝗗𝗘 𝗗𝗢𝗡𝗗𝗘 𝗩𝗜𝗘𝗡𝗘𝗦! ❤️\u200d🩹⚽️  #Respect #Yangel #Venezuela #SoloVenex',
#    'user': {'name': 'SOLOVENEX',
#     'username': '@SOLOVENEX_',
#     'profile_id': '1812834507617124352',
#     'avatar': 'https://pbs.twimg.com/profile_images/1812834507617124352/nSbyIO4J_bigger.jpg'},
#    'date': 'Jun 6, 2024 · 12:45 PM UTC',
#    'is-retweet': False,
#    'is-pinned': False,
#    'external-link': '',
#    'replying-to': [],
#    'quoted-post': {},
#    'stats': {'comments': 18, 'retweets': 181, 'quotes': 28, 'likes': 915},
#    'pictures': [],
#    'videos': ['https://video.twimg.com/amplify_video/1798697435927326721/pl/YqC4CGsJl1wGpqOo.m3u8?tag=16'],
#    'gifs': []},
#   {'link': 'https://twitter.com/SOLOVENEX_/status/1798530870883819918#m',
#    'text': '',
#    'user': {'name': 'SOLOVENEX',
#     'username': '@SOLOVENEX_',
#     'profile_id': '1812834507617124352',
#     'avatar': 'https://pbs.twimg.com/profile_images/1812834507617124352/nSbyIO4J_bigger.jpg'},
#    'date': 'Jun 6, 2024 · 1:42 AM UTC',
#    'is-retweet': False,
#    'is-pinned': False,
#    'external-link': '',
#    'replying-to': ['@carlostaracher'],
#    'quoted-post': {},
#    'stats': {'comments': 0, 'retweets': 0, 'quotes': 0, 'likes': 5},
#    'pictures': [],
#    'videos': [],
#    'gifs': ['https://video.twimg.com/tweet_video/GPWqSmnXMAAV9Pn.mp4']},
#   {'link': 'https://twitter.com/SOLOVENEX_/status/1798528448308154795#m',
#    'text': '📸 ¡𝗣𝗮𝗿𝗮 𝗲𝗹 𝗿𝗲𝗰𝘂𝗲𝗿𝗱𝗼! Las selecciones de Pakistán y Arabia Saudita se miden este jueves por las Eliminatorias de AFC para la Copa del Mundo.   ¿𝗣𝗼𝗿 𝗾𝘂𝗲́ 𝗲𝘀 𝗻𝗼𝘁𝗶𝗰𝗶𝗮? Porque el seleccionado pakistaní cuenta en su delegación con el venezolano Claudio Altieri, jefe de alto rendimiento, y quien previo al partido, nos regaló esta postal junto a Roberto Mancini, actual estratega de los ‘saudís’.  Otro embajador criollo en el balompie internacional: ¡𝗽𝗼𝗱𝗲𝗿 𝘃𝗶𝗻𝗼𝘁𝗶𝗻𝘁𝗼! 🇻🇪  #VenEx #Pakistán #AFC #SoloVenex',
#    'user': {'name': 'SOLOVENEX',
#     'username': '@SOLOVENEX_',
#     'profile_id': '1812834507617124352',
#     'avatar': 'https://pbs.twimg.com/profile_images/1812834507617124352/nSbyIO4J_bigger.jpg'},
#    'date': 'Jun 6, 2024 · 1:32 AM UTC',
#    'is-retweet': False,
#    'is-pinned': False,
#    'external-link': '',
#    'replying-to': [],
#    'quoted-post': {},
#    'stats': {'comments': 1, 'retweets': 12, 'quotes': 0, 'likes': 104},
#    'pictures': ['https://pbs.twimg.com/media/GPWoFwYXQAAxsbG.jpg'],
#    'videos': [],
#    'gifs': []},
#   {'link': 'https://twitter.com/SOLOVENEX_/status/1798490893374353781#m',
#    'text': '.@10Ronaldinho llegó a 𝗩𝗘𝗡𝗘𝗭𝗨𝗘𝗟𝗔 🇻🇪  Este 06 y 07 jugará la @LigaMonumental_.  ¿Primer rival? @vikingoscaribe de @Arango_18.  #LigaMonumental #Dinho #SoloVenex',
#    'user': {'name': 'SOLOVENEX',
#     'username': '@SOLOVENEX_',
#     'profile_id': '1812834507617124352',
#     'avatar': 'https://pbs.twimg.com/profile_images/1812834507617124352/nSbyIO4J_bigger.jpg'},
#    'date': 'Jun 5, 2024 · 11:03 PM UTC',
#    'is-retweet': False,
#    'is-pinned': False,
#    'external-link': '',
#    'replying-to': [],
#    'quoted-post': {},
#    'stats': {'comments': 0, 'retweets': 3, 'quotes': 0, 'likes': 33},
#    'pictures': ['https://pbs.twimg.com/media/GPWF7rOXgAEEX9Y.jpg',
#     'https://pbs.twimg.com/media/GPWF7rPXgAAnyjf.jpg'],
#    'videos': [],
#    'gifs': []},
#   {'link': 'https://twitter.com/SOLOVENEX_/status/1798481911167541455#m',
#    'text': 'https://piped.video/9j0rozfIKeo?si=8NH4ZaOdPybskoyu',
#    'user': {'name': 'SOLOVENEX',
#     'username': '@SOLOVENEX_',
#     'profile_id': '1812834507617124352',
#     'avatar': 'https://pbs.twimg.com/profile_images/1812834507617124352/nSbyIO4J_bigger.jpg'},
#    'date': 'Jun 5, 2024 · 10:27 PM UTC',
#    'is-retweet': False,
#    'is-pinned': False,
#    'external-link': '',
#    'replying-to': [],
#    'quoted-post': {},
#    'stats': {'comments': 0, 'retweets': 0, 'quotes': 0, 'likes': 2},
#    'pictures': [],
#    'videos': [],
#    'gifs': []},
#   {'link': 'https://twitter.com/SOLOVENEX_/status/1798481757479821694#m',
#    'text': '.@bochabatista sobre el caso 𝗠𝗔𝗟𝗗𝗜𝗡𝗜.  ¿Cómo funciona el scout en Venezuela?   ¡Disponible en nuestro canal de YouTube!   #BochaBatistaEnSOLOVENEX',
#    'user': {'name': 'SOLOVENEX',
#     'username': '@SOLOVENEX_',
#     'profile_id': '1812834507617124352',
#     'avatar': 'https://pbs.twimg.com/profile_images/1812834507617124352/nSbyIO4J_bigger.jpg'},
#    'date': 'Jun 5, 2024 · 10:27 PM UTC',
#    'is-retweet': False,
#    'is-pinned': False,
#    'external-link': '',
#    'replying-to': [],
#    'quoted-post': {},
#    'stats': {'comments': 1, 'retweets': 16, 'quotes': 0, 'likes': 131},
#    'pictures': [],
#    'videos': ['https://video.twimg.com/amplify_video/1798481467611205632/pl/BL-CD0r2mHtez4AZ.m3u8?tag=16'],
#    'gifs': []},
#   {'link': 'https://twitter.com/SOLOVENEX_/status/1798332869343142375#m',
#    'text': '🇻🇪 El primer día siendo vinotintos…   • Alessandro Milani y Lorenzo D’Agostini se sumaron a los trabajos con @juvenilesfvf en Murcia, España.   Día 0️⃣1️⃣ para los jugadores de la Lazio.  #Vinotinto #Lazio #Scouting #SoloVenex',
#    'user': {'name': 'SOLOVENEX',
#     'username': '@SOLOVENEX_',
#     'profile_id': '1812834507617124352',
#     'avatar': 'https://pbs.twimg.com/profile_images/1812834507617124352/nSbyIO4J_bigger.jpg'},
#    'date': 'Jun 5, 2024 · 12:35 PM UTC',
#    'is-retweet': False,
#    'is-pinned': False,
#    'external-link': '',
#    'replying-to': [],
#    'quoted-post': {},
#    'stats': {'comments': 16, 'retweets': 96, 'quotes': 3, 'likes': 708},
#    'pictures': ['https://pbs.twimg.com/media/GPT2IbVXoAA23Ri.jpg'],
#    'videos': [],
#    'gifs': []},
#   {'link': 'https://twitter.com/SOLOVENEX_/status/1798019119234609605#m',
#    'text': '🇺🇸 🇻🇪 | El guardameta 𝗝𝗨𝗔𝗡 𝗥𝗢𝗝𝗔𝗦 (𝟮𝟬𝟬𝟴), nacido en USA, de padre venezolano, fue invitado a entrenar con la selección de Brasil en el último ciclo de preparación previo a Copa América.   Rojas, quien forma parte de las academias del @OrlandoCitySC, equipo de la ciudad de la que es nativo, acompañó a la selección “𝙘𝙖𝙣𝙖𝙧𝙞𝙣𝙝𝙖” desde el pasado 30 de mayo hasta este lunes 03 de junio.   “𝗔𝗴𝗿𝗮𝗱𝗲𝗰𝗶𝗱𝗼 𝗽𝗼𝗿 𝗲𝘀𝘁𝗮 𝗼𝗽𝗼𝗿𝘁𝘂𝗻𝗶𝗱𝗮𝗱”, posteó el jugador en la red social Instagram.   #VenEx #Brasil #Scout #SoloVenex   | 📄 Con info de jovenespromesasve/IG |   | 📸 Con imágenes de rafaelribeirorio/IG |',
#    'user': {'name': 'SOLOVENEX',
#     'username': '@SOLOVENEX_',
#     'profile_id': '1812834507617124352',
#     'avatar': 'https://pbs.twimg.com/profile_images/1812834507617124352/nSbyIO4J_bigger.jpg'},
#    'date': 'Jun 4, 2024 · 3:48 PM UTC',
#    'is-retweet': False,
#    'is-pinned': False,
#    'external-link': '',
#    'replying-to': [],
#    'quoted-post': {},
#    'stats': {'comments': 8, 'retweets': 26, 'quotes': 1, 'likes': 113},
#    'pictures': ['https://pbs.twimg.com/media/GPPY21TWUAEh-5j.jpg'],
#    'videos': [],
#    'gifs': []},
#   {'link': 'https://twitter.com/SOLOVENEX_/status/1797973747858587915#m',
#    'text': '🇮🇹🇻🇪🆕 | 𝗡𝗼𝘃𝗲𝗱𝗮𝗱𝗲𝘀 𝗲𝗻 @juvenilesfvf:  𝗟𝗢𝗥𝗘𝗡𝗭𝗢 𝗗’𝗔𝗚𝗢𝗦𝗧𝗜𝗡𝗜 y 𝗔𝗟𝗘𝗦𝗦𝗔𝗡𝗗𝗥𝗢 𝗠𝗜𝗟𝗔𝗡𝗜, ambos categoría 𝟮𝟬𝟬𝟱, son dos de las grandes novedades del último listado de Ricardo Valiño de cara al módulo U20 que se realizará en Murcia, España.   🤓 • ¿𝗤𝘂𝗶𝗲́𝗻𝗲𝘀 𝘀𝗼𝗻? ¿𝗬 𝗱𝗼́𝗻𝗱𝗲 𝗷𝘂𝗲𝗴𝗮𝗻? ⬇️  ➤ 𝗗’𝗔𝗚𝗢𝗦𝗧𝗜𝗡𝗜: delantero centro nacido en Estados Unidos, de padres venezolanos, que previo a su llegada a la #SSLazio U19, tuvo un paso formativo por el Inter Miami (MLS Next PRO)  ➤ 𝗠𝗜𝗟𝗔𝗡𝗜 por su parte, es un lateral izquierdo de 1.78 de altura que también hace vida en la #SSLazio categoría U19. Nacido en Latina, Italia, de abuelo venezolano y quien incluso, ya suma 19 convocatorias en las inferiores de la “azzurri”.  Ambos, con un deseo intacto: ¡𝘃𝗲𝘀𝘁𝗶𝗿 𝗹𝗼𝘀 𝗰𝗼𝗹𝗼𝗿𝗲𝘀 𝗱𝗲 𝗺𝗮 𝘀𝗲𝗹𝗲𝗰𝗰𝗶𝗼́𝗻 𝗻𝗮𝗰𝗶𝗼𝗻𝗮𝗹 𝗱𝗲 𝗩𝗲𝗻𝗲𝘇𝘂𝗲𝗹𝗮! Lee más sobre ellos en nuestra página web: solovenex.com #Vinotinto #Lazio #Scouting #SoloVenex',
#    'user': {'name': 'SOLOVENEX',
#     'username': '@SOLOVENEX_',
#     'profile_id': '1812834507617124352',
#     'avatar': 'https://pbs.twimg.com/profile_images/1812834507617124352/nSbyIO4J_bigger.jpg'},
#    'date': 'Jun 4, 2024 · 12:48 PM UTC',
#    'is-retweet': False,
#    'is-pinned': False,
#    'external-link': '',
#    'replying-to': [],
#    'quoted-post': {},
#    'stats': {'comments': 5, 'retweets': 40, 'quotes': 1, 'likes': 301},
#    'pictures': ['https://pbs.twimg.com/media/GPOvl3vXUAAxZMU.jpg'],
#    'videos': [],
#    'gifs': []},
#   {'link': 'https://twitter.com/SOLOVENEX_/status/1797819939212103951#m',
#    'text': '“𝐔𝐍𝐀 𝐓𝐀𝐑𝐃𝐄 𝐃𝐄 𝐅𝐔𝐓𝐕𝐄…” ⚽️🥃🚬',
#    'user': {'name': 'SOLOVENEX',
#     'username': '@SOLOVENEX_',
#     'profile_id': '1812834507617124352',
#     'avatar': 'https://pbs.twimg.com/profile_images/1812834507617124352/nSbyIO4J_bigger.jpg'},
#    'date': 'Jun 4, 2024 · 2:37 AM UTC',
#    'is-retweet': False,
#    'is-pinned': False,
#    'external-link': '',
#    'replying-to': [],
#    'quoted-post': {},
#    'stats': {'comments': 2, 'retweets': 12, 'quotes': 0, 'likes': 211},
#    'pictures': ['https://pbs.twimg.com/media/GPMjtAqXYAAwzVi.jpg'],
#    'videos': [],
#    'gifs': []},
#   {'link': 'https://twitter.com/SOLOVENEX_/status/1797672391700881779#m',
#    'text': '“𝑫𝒆𝒎𝒐𝒔𝒕𝒓𝒆𝒎𝒐𝒔 𝒈𝒓𝒂𝒏𝒅𝒆𝒛𝒂, 𝒒𝒖𝒆 𝒂𝒉𝒐𝒓𝒂 𝒗𝒊𝒆𝒏𝒆 𝒍𝒐 𝒃𝒖𝒆𝒏𝒐…” ~ @SeleVinotinto 🏆🇻🇪  ✨ ¡Inicia la ruta a la 𝑪𝒐𝒑𝒂 𝑨𝒎𝒆́𝒓𝒊𝒄𝒂! ✨  ¿Qué le dirías a la delegación vinotinto? ⤵️  #PoderVinotintoCA2024',
#    'user': {'name': 'SOLOVENEX',
#     'username': '@SOLOVENEX_',
#     'profile_id': '1812834507617124352',
#     'avatar': 'https://pbs.twimg.com/profile_images/1812834507617124352/nSbyIO4J_bigger.jpg'},
#    'date': 'Jun 3, 2024 · 4:51 PM UTC',
#    'is-retweet': False,
#    'is-pinned': False,
#    'external-link': '',
#    'replying-to': [],
#    'quoted-post': {},
#    'stats': {'comments': 4, 'retweets': 11, 'quotes': 2, 'likes': 102},
#    'pictures': ['https://pbs.twimg.com/media/GPKc1QSWwAAhkk9.jpg'],
#    'videos': [],
#    'gifs': []},
#   {'link': 'https://twitter.com/SOLOVENEX_/status/1797420942450446827#m',
#    'text': '.@bochabatista les tiene una invitación…  ¡Los esperamos en el canal de YouTube!   #BochaBatistaEnSOLOVENEX 🍿⚽️🇻🇪  https://piped.video/9j0rozfIKeo?si=B87pxdv7n6t-rx4D',
#    'user': {'name': 'SOLOVENEX',
#     'username': '@SOLOVENEX_',
#     'profile_id': '1812834507617124352',
#     'avatar': 'https://pbs.twimg.com/profile_images/1812834507617124352/nSbyIO4J_bigger.jpg'},
#    'date': 'Jun 3, 2024 · 12:12 AM UTC',
#    'is-retweet': False,
#    'is-pinned': False,
#    'external-link': '',
#    'replying-to': [],
#    'quoted-post': {},
#    'stats': {'comments': 3, 'retweets': 9, 'quotes': 0, 'likes': 102},
#    'pictures': [],
#    'videos': ['https://video.twimg.com/amplify_video/1797420883826421760/pl/0BMA9m1qKKRpzCLA.m3u8?tag=16'],
#    'gifs': []},
#   {'link': 'https://twitter.com/SOLOVENEX_/status/1797418295991353685#m',
#    'text': '🚨 ¡YA ESTAMOS FT. @bochabatista! 🚨  https://piped.video/9j0rozfIKeo?si=unA0DtW8uByc04pb',
#    'user': {'name': 'SOLOVENEX',
#     'username': '@SOLOVENEX_',
#     'profile_id': '1812834507617124352',
#     'avatar': 'https://pbs.twimg.com/profile_images/1812834507617124352/nSbyIO4J_bigger.jpg'},
#    'date': 'Jun 3, 2024 · 12:01 AM UTC',
#    'is-retweet': False,
#    'is-pinned': False,
#    'external-link': '',
#    'replying-to': [],
#    'quoted-post': {},
#    'stats': {'comments': 0, 'retweets': 0, 'quotes': 0, 'likes': 6},
#    'pictures': [],
#    'videos': [],
#    'gifs': []},
#   {'link': 'https://twitter.com/SOLOVENEX_/status/1797310128720347567#m',
#    'text': 'https://piped.video/@solovenex_?si=cdbk_IF_UaU_VL-K',
#    'user': {'name': 'SOLOVENEX',
#     'username': '@SOLOVENEX_',
#     'profile_id': '1812834507617124352',
#     'avatar': 'https://pbs.twimg.com/profile_images/1812834507617124352/nSbyIO4J_bigger.jpg'},
#    'date': 'Jun 2, 2024 · 4:51 PM UTC',
#    'is-retweet': False,
#    'is-pinned': False,
#    'external-link': '',
#    'replying-to': [],
#    'quoted-post': {},
#    'stats': {'comments': 0, 'retweets': 0, 'quotes': 0, 'likes': 2},
#    'pictures': [],
#    'videos': [],
#    'gifs': []},
#   {'link': 'https://twitter.com/SOLOVENEX_/status/1797310042619744524#m',
#    'text': '¡𝐄𝐗𝐂𝐋𝐔𝐒𝐈𝐕𝐀 con el @bochabatista! 🇻🇪  𝐄𝐒𝐓𝐑𝐄𝐍𝐎: 02 de junio, 8:00 PM.   ¡Te esperamos en el canal de 𝐘𝐎𝐔𝐓𝐔𝐁𝐄!   #ElBochaEnSOLOVENEX',
#    'user': {'name': 'SOLOVENEX',
#     'username': '@SOLOVENEX_',
#     'profile_id': '1812834507617124352',
#     'avatar': 'https://pbs.twimg.com/profile_images/1812834507617124352/nSbyIO4J_bigger.jpg'},
#    'date': 'Jun 2, 2024 · 4:51 PM UTC',
#    'is-retweet': False,
#    'is-pinned': False,
#    'external-link': '',
#    'replying-to': [],
#    'quoted-post': {},
#    'stats': {'comments': 3, 'retweets': 11, 'quotes': 1, 'likes': 91},
#    'pictures': ['https://pbs.twimg.com/media/GPFT80IXYAEpKh6.jpg'],
#    'videos': [],
#    'gifs': []},
#   {'link': 'https://twitter.com/SOLOVENEX_/status/1797277244877934670#m',
#    'text': '𝗥𝗢𝗡𝗗𝗢́𝗡: 𝗘𝗟 𝗥𝗘𝗬 de @TheChampions.  ➤ 𝗖𝗔𝗠𝗣𝗘𝗢́𝗡 del torneo con los @Tuzos. ➤ 𝗚𝗢𝗟𝗘𝗔𝗗𝗢𝗥 del torneo con (09 goles). ➤ 𝗠𝗩𝗣: marcó en cuartos, semis y la final.  • Pachuca venció 3-0 a @ColumbusCrew con 𝗗𝗢𝗕𝗟𝗘𝗧𝗘 del venezolano y ahora representarán a CONCACAF en el Mundial de Clubes. 𝗚𝗟𝗔𝗗𝗜𝗔𝗗𝗢𝗥.  🦍👑⚽️🇻🇪  #VenEx #Rondón #Pachuca #SoloVenex',
#    'user': {'name': 'SOLOVENEX',
#     'username': '@SOLOVENEX_',
#     'profile_id': '1812834507617124352',
#     'avatar': 'https://pbs.twimg.com/profile_images/1812834507617124352/nSbyIO4J_bigger.jpg'},
#    'date': 'Jun 2, 2024 · 2:41 PM UTC',
#    'is-retweet': False,
#    'is-pinned': False,
#    'external-link': '',
#    'replying-to': [],
#    'quoted-post': {},
#    'stats': {'comments': 0, 'retweets': 11, 'quotes': 0, 'likes': 53},
#    'pictures': [],
#    'videos': ['https://video.twimg.com/amplify_video/1797277121695383552/pl/Iu4ZpyVE9SDaDaTA.m3u8?tag=14'],
#    'gifs': []},
#   {'link': 'https://twitter.com/SOLOVENEX_/status/1796916407524806686#m',
#    'text': '¡𝑱𝒖𝒏𝒊𝒐 𝒔𝒐𝒍𝒐 𝒔𝒊𝒈𝒏𝒊𝒇𝒊𝒄𝒂 𝒖𝒏𝒂 𝒄𝒐𝒔𝒂! | 🏆🇻🇪  #PoderVinotintoCA2024',
#    'user': {'name': 'SOLOVENEX',
#     'username': '@SOLOVENEX_',
#     'profile_id': '1812834507617124352',
#     'avatar': 'https://pbs.twimg.com/profile_images/1812834507617124352/nSbyIO4J_bigger.jpg'},
#    'date': 'Jun 1, 2024 · 2:47 PM UTC',
#    'is-retweet': False,
#    'is-pinned': False,
#    'external-link': '',
#    'replying-to': [],
#    'quoted-post': {},
#    'stats': {'comments': 2, 'retweets': 2, 'quotes': 0, 'likes': 30},
#    'pictures': [],
#    'videos': ['https://video.twimg.com/amplify_video/1796916273118355456/pl/uVpoWGWiNfX5mMZ-.m3u8?tag=16'],
#    'gifs': []},
#   {'link': 'https://twitter.com/SOLOVENEX_/status/1796673383788171646#m',
#    'text': '#NuevaFotoDePerfil',
#    'user': {'name': 'SOLOVENEX',
#     'username': '@SOLOVENEX_',
#     'profile_id': '1812834507617124352',
#     'avatar': 'https://pbs.twimg.com/profile_images/1812834507617124352/nSbyIO4J_bigger.jpg'},
#    'date': 'May 31, 2024 · 10:41 PM UTC',
#    'is-retweet': False,
#    'is-pinned': False,
#    'external-link': '',
#    'replying-to': [],
#    'quoted-post': {},
#    'stats': {'comments': 0, 'retweets': 0, 'quotes': 0, 'likes': 18},
#    'pictures': ['https://pbs.twimg.com/media/GO8Q63CW0AENK5B.jpg'],
#    'videos': [],
#    'gifs': []},
#   {'link': 'https://twitter.com/SOLOVENEX_/status/1796649651745026302#m',
#    'text': '#VenEx | Mutasem Kountar se afianza desde la línea de cal en Norteamérica: https://solovenex.com/mutasem-kountar-se-afianza-desde-la-linea-de-cal-en-norteamerica/',
#    'user': {'name': 'SOLOVENEX',
#     'username': '@SOLOVENEX_',
#     'profile_id': '1812834507617124352',
#     'avatar': 'https://pbs.twimg.com/profile_images/1812834507617124352/nSbyIO4J_bigger.jpg'},
#    'date': 'May 31, 2024 · 9:07 PM UTC',
#    'is-retweet': False,
#    'is-pinned': False,
#    'external-link': '',
#    'replying-to': [],
#    'quoted-post': {},
#    'stats': {'comments': 0, 'retweets': 2, 'quotes': 0, 'likes': 5},
#    'pictures': [],
#    'videos': [],
#    'gifs': []}],
#  'threads': []}

# %%
print(tweets2)
# Out:
# {'tweets': [{'link': 'https://twitter.com/SOLOVENEX_/status/1837618723538014486#m', 'text': 'Somos venezolanos. ¡Somos hermanos!   𝘼𝙍𝘼𝙈𝘽𝙐𝙍𝙐 🔗 𝙈𝘼𝘾𝙃𝙄́𝙎 = 🫂❤️🇻🇪  #VenEx', 'user': {'name': 'SOLOVENEX', 'username': '@SOLOVENEX_', 'profile_id': '1812834507617124352', 'avatar': 'https://pbs.twimg.com/profile_images/1812834507617124352/nSbyIO4J_bigger.jpg'}, 'date': 'Sep 21, 2024 · 10:23 PM UTC', 'is-retweet': True, 'is-pinned': False, 'external-link': '', 'replying-to': [], 'quoted-post': {}, 'stats': {'comments': 3, 'retweets': 75, 'quotes': 1, 'likes': 762}, 'pictures': ['https://pbs.twimg.com/media/GYCIe3wXMAAa2eq.jpg'], 'videos': [], 'gifs': []}, {'link': 'https://twitter.com/SOLOVENEX_/status/1837883159553208575#m', 'text': 'No dejemos ir este momento (😂)   ¡Comenta si tienes un pana así! ⬇️  | 🎥 Vía: @Lavinotintopod |', 'user': {'name': 'SOLOVENEX', 'username': '@SOLOVENEX_', 'profile_id': '1812834507617124352', 'avatar': 'https://pbs.twimg.com/profile_images/1812834507617124352/nSbyIO4J_bigger.jpg'}, 'date': 'Sep 22, 2024 · 3:54 PM UTC', 'is-retweet': False, 'is-pinned': False, 'external-link': '', 'replying-to': [], 'quoted-post': {}, 'stats': {'comments': 0, 'retweets': 1, 'quotes': 0, 'likes': 3}, 'pictures': [], 'videos': ['https://video.twimg.com/amplify_video/1837883091748012032/pl/rRepCmym90IvpMvx.m3u8?tag=16'], 'gifs': []}, {'link': 'https://twitter.com/SOLOVENEX_/status/1837660758093844989#m', 'text': '𝗝𝗛𝗢𝗡𝗗𝗘𝗥 𝗖𝗔́𝗗𝗜𝗭 continúa siendo factor diferencial con el Club León en la Liga MX y este sábado definió la victoria 1-0 sobre Atlético San Luis.   El delantero caraqueño disputó 66’ minutos y anotó su 𝗤𝗨𝗜𝗡𝗧𝗢 𝗚𝗢𝗟 en ocho partidos con ‘los felinos’.  .@SofascoreLA valoró su actuación en 7.4 siendo uno de los mejores de su equipo y consolidándose como uno de los ‘9’  más efectivos del fútbol mexicano.   “¡𝗧𝗥𝗔𝗡𝗤𝗨𝗜𝗟𝗢𝗦, 𝗬𝗢 𝗘𝗦𝗧𝗢𝗬 𝗔𝗤𝗨𝗜́!” — 🇻🇪  #VenEx #LigaMX #Cádiz #SoloVenex   | 📸 @clubleonfc |', 'user': {'name': 'SOLOVENEX', 'username': '@SOLOVENEX_', 'profile_id': '1812834507617124352', 'avatar': 'https://pbs.twimg.com/profile_images/1812834507617124352/nSbyIO4J_bigger.jpg'}, 'date': 'Sep 22, 2024 · 1:10 AM UTC', 'is-retweet': False, 'is-pinned': False, 'external-link': '', 'replying-to': [], 'quoted-post': {}, 'stats': {'comments': 0, 'retweets': 26, 'quotes': 0, 'likes': 250}, 'pictures': ['https://pbs.twimg.com/media/GYCutGOW4AAkcAF.jpg'], 'videos': [], 'gifs': []}, {'link': 'https://twitter.com/clubleonfc/status/1837648994803065343#m', 'text': '¡GOOOOOOOOOOOOOOOL DE LA FIEEEEERA!  ¡GRÍTALO CON @Telcel!', 'user': {'name': 'Club León', 'username': '@clubleonfc', 'profile_id': '1825880916436160512', 'avatar': 'https://pbs.twimg.com/profile_images/1825880916436160512/K5lxWYth_bigger.jpg'}, 'date': 'Sep 22, 2024 · 12:23 AM UTC', 'is-retweet': True, 'is-pinned': False, 'external-link': '', 'replying-to': [], 'quoted-post': {}, 'stats': {'comments': 18, 'retweets': 20, 'quotes': 4, 'likes': 370}, 'pictures': [], 'videos': ['https://video.twimg.com/ext_tw_video/1837648961722560512/pu/pl/Id7vlgiZg-UFQf7S.m3u8?tag=12'], 'gifs': []}, {'link': 'https://twitter.com/SOLOVENEX_/status/1837508611389444545#m', 'text': '“𝗔 𝗺𝗶 𝗺𝗲 𝗽𝗮𝗿𝗲𝗰𝗲 𝘂𝗻𝗮 𝗶𝗿𝗿𝗲𝘀𝗽𝗼𝗻𝘀𝗮𝗯𝗶𝗹𝗶𝗱𝗮𝗱 𝘀𝘂𝗯𝗶𝗿 𝗮 𝗹𝗮 𝗮𝗹𝘁𝘂𝗿𝗮 𝘆 𝗻𝗼 𝘁𝗼𝗺𝗮𝗿 𝘂𝗻 𝘁𝗶𝗽𝗼 𝗱𝗲 𝗽𝗿𝗲𝘃𝗶𝘀𝗶𝗼́𝗻”. 🎙️🔥🇻🇪  La palabra de César Farías a @JOSEHUGOILLERA sobre el factor altura. “Venezuela lo acaba de pagar muy caro”, declaró el estratega en esta entrevista.  La @SeleVinotinto viene de caer 4-0 en El Alto (vs Bolivia) por las Eliminatorias CONMEBOL.   📲 • ¡Te leemos en los comentarios! ⬇️  #Vinotinto #Farías #Video #SoloVenex', 'user': {'name': 'SOLOVENEX', 'username': '@SOLOVENEX_', 'profile_id': '1812834507617124352', 'avatar': 'https://pbs.twimg.com/profile_images/1812834507617124352/nSbyIO4J_bigger.jpg'}, 'date': 'Sep 21, 2024 · 3:06 PM UTC', 'is-retweet': True, 'is-pinned': False, 'external-link': '', 'replying-to': [], 'quoted-post': {}, 'stats': {'comments': 30, 'retweets': 60, 'quotes': 18, 'likes': 280}, 'pictures': [], 'vid ...

# %%
tweets2.keys()
# Out:
# dict_keys(['tweets', 'threads'])

# %%
tweets2["tweets"][0]
# Out:
# {'link': 'https://twitter.com/SOLOVENEX_/status/1837618723538014486#m',
#  'text': 'Somos venezolanos. ¡Somos hermanos!   𝘼𝙍𝘼𝙈𝘽𝙐𝙍𝙐 🔗 𝙈𝘼𝘾𝙃𝙄́𝙎 = 🫂❤️🇻🇪  #VenEx',
#  'user': {'name': 'SOLOVENEX',
#   'username': '@SOLOVENEX_',
#   'profile_id': '1812834507617124352',
#   'avatar': 'https://pbs.twimg.com/profile_images/1812834507617124352/nSbyIO4J_bigger.jpg'},
#  'date': 'Sep 21, 2024 · 10:23 PM UTC',
#  'is-retweet': True,
#  'is-pinned': False,
#  'external-link': '',
#  'replying-to': [],
#  'quoted-post': {},
#  'stats': {'comments': 3, 'retweets': 75, 'quotes': 1, 'likes': 762},
#  'pictures': ['https://pbs.twimg.com/media/GYCIe3wXMAAa2eq.jpg'],
#  'videos': [],
#  'gifs': []}

# %% [markdown]
# De los tweets elijo la info que quiero y la guardo en un DF

# %%
##lo hago lista
data= {
    'link':[],
    'text':[],
    'date':[],
    'user':[],
    'likes':[],
    'quotes':[],
    'retweets':[],
    'comments':[]


}
for tweet in tweets2 ['tweets']:
  data['link'].append(tweet['link'])
  data['text'].append(tweet['text'])
  data['date'].append(tweet['date'])
  data['user'].append(tweet['user']['username'])
  data['likes'].append(tweet['stats']['likes'])
  data['quotes'].append(tweet['stats']['quotes'])
  data['retweets'].append(tweet['stats']['retweets'])
  data['comments'].append(tweet['stats']['comments'])

# %%
data
df= pd.DataFrame(data)
df.head()
# Out:
#                                                 link  \
# 0  https://twitter.com/SOLOVENEX_/status/18376187...
# 1  https://twitter.com/SOLOVENEX_/status/18378831...
# 2  https://twitter.com/SOLOVENEX_/status/18376607...
# 3  https://twitter.com/clubleonfc/status/18376489...
# 4  https://twitter.com/SOLOVENEX_/status/18375086...
#
#                                                 text  \
# 0  Somos venezolanos. ¡Somos hermanos!   𝘼𝙍𝘼𝙈𝘽𝙐𝙍𝙐...
# 1  No dejemos ir este momento (😂)   ¡Comenta si t...
# 2  𝗝𝗛𝗢𝗡𝗗𝗘𝗥 𝗖𝗔́𝗗𝗜𝗭 continúa siendo factor diferenc...
# 3  ¡GOOOOOOOOOOOOOOOL DE LA FIEEEEERA!  ¡GRÍTALO ...
# 4  “𝗔 𝗺𝗶 𝗺𝗲 𝗽𝗮𝗿𝗲𝗰𝗲 𝘂𝗻𝗮 𝗶𝗿𝗿𝗲𝘀𝗽𝗼𝗻𝘀𝗮𝗯𝗶𝗹𝗶𝗱𝗮𝗱 𝘀𝘂𝗯𝗶𝗿 𝗮 ...
#
#                           date         user  likes  quotes  retweets  comments
# 0  Sep 21, 2024 · 10:23 PM UTC  @SOLOVENEX_    762       1        75         3
# 1   Sep 22, 2024 · 3:54 PM UTC  @SOLOVENEX_      3       0         1         0
# 2   Sep 22, 2024 · 1:10 AM UTC  @SOLOVENEX_    250       0        26         0
# 3  Sep 22, 2024 · 12:23 AM UTC  @clubleonfc    370       4        20        18
# 4   Sep 21, 2024 · 3:06 PM UTC  @SOLOVENEX_    280      18        60        30

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 514 entries, 0 to 513
# Data columns (total 8 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   link      514 non-null    object
#  1   text      514 non-null    object
#  2   date      514 non-null    object
#  3   user      514 non-null    object
#  4   likes     514 non-null    int64
#  5   quotes    514 non-null    int64
#  6   retweets  514 non-null    int64
#  7   comments  514 non-null    int64
# dtypes: int64(4), object(4)
# memory usage: 32.3+ KB

# %%
df['date'] = pd.to_datetime(df['date'], format='%b %d, %Y · %I:%M %p %Z', errors='coerce')

# %%
df.to_csv('info_solovenex.csv', index = False)

# %% [markdown]
# Uso la funcion get profile info

# %%
##no tiene parametros que encuentre utiles
##username: username of the page to scrape
##max_retries: max retries to scrape a page. Default is 5
##instance: Nitter instance to use. Default is None

# %%
solovenex= scraper.get_profile_info(username='solovenex')
#dfsolovenex=pd.DataFrame(solovenex)
#textsolovenex=dfsolovenex.to_csv(index=False)
# Out:
# INFO:root:No instance specified, using random instance https://nitter.privacydev.net
# WARNING:root:Fetching error: User "solovenex" has been suspended

# %%
print(solovenex)
# Out:
# None

# %% [markdown]
# Ahora le paso el DF de la info del profile a Gemini para ver como responde

# %%
##poniendolo como df es como mejor contesta....

contexto = f"""Sos un agente de social media de una empresa de futbol, te dan la siguiente informarcion:  {df} para que comiences tu analisis informacion sobre el perfil de un jugador de futbol obtenido de twitter."""


pregunta = f""" Tu trabajo es informarnos cuantos tweets tiene, seguidores, likes y toda la informacion que consideres relavante. Solamente utilizando los datos que estan aqui"""

# Prompt con el contexto y la pregunta
prompt = f"{contexto}\n\n{pregunta}"

# Generar la respuesta utilizando el prompt actualizado
responses = model.generate_content(prompt, generation_config=generation_config, stream=True)

# Imprimir la respuesta generada
  # Genera la respuesta
for response in responses:
    print(response.text, end="")
# Out:
# ## Análisis del perfil de @julianalvarezzz en Twitter:
#
# **Información General:**
#
# * **Nombre de usuario:** @julianalvarezzz
# * **ID:** 1314737738
# * **Descripción:** Jugador de Manchester City
# * **Fecha de unión:** 6:17 PM - 29 Mar 2013
#
# **Estadísticas:**
#
# * **Tweets:** 799
# * **Seguidores:** 328,409
# * **Siguiendo:** 225
# * **Likes:** 2,076
# * **Media:** 0 (No se especifica el tipo de contenido multimedia)
#
# **Análisis:**
#
# * **Popularidad:** @julianalvarezzz es un jugador de fútbol muy popular en Twitter con un gran número de seguidores.
# * **Actividad:**  Es un usuario activo en la plataforma con un número considerable de tweets, likes y seguidores.
# * **Interacción:**  Su ratio de seguidores a tweets (328,409 / 799 = 411) sugiere que sus tweets tienen un alto nivel de interacción.
# * **Engagement:** El número de likes y seguidores indica que su contenido es atractivo para sus fans.
# * **Contenido:**  No se especifica el tipo de contenido multimedia que publica, pero es posible que incluya fotos, videos o enlaces a artículos relacionados con su carrera futbolística.
#
# **Recomendaciones:**
#
# * **Análisis de contenido:**  Se necesita un análisis más profundo del contenido de los tweets para comprender mejor su estrategia de comunicación en Twitter.
# * **Engagement:**  Es importante mantener una interacción constante con sus seguidores respondiendo a comentarios, realizando concursos o preguntas y creando contenido atractivo.
# * **Análisis de la competencia:**  Comparar su perfil con otros jugadores de fútbol de su mismo equipo o de otros equipos puede ser útil para identificar oportunidades de mejora.
# * **Utilización de la plataforma:**  Explorar las diferentes funciones de Twitter como las historias, los hashtags y los anuncios para aumentar su alcance y engagement.
#
# **En resumen:** @julianalvarezzz es un jugador de fútbol con una gran presencia en Twitter. Su actividad y el alto nivel de interacción sugieren que es un usuario activo que conecta con sus fans. Un análisis más profundo de su contenido y estrategias de comunicación podría optimizar su presencia en la plataforma.

# %% [markdown]
# Armo una funcion para que me traiga la info de los tweets que quiero y la pase a un DF

# %%
#scraper=Nitter()

def create_tweets_dataset(username, n_of_tweets):
    tweets = scraper.get_tweets(username, mode="user", number=n_of_tweets)

    data = {
        'link': [],
        'text': [],
        'user': [],
        'likes': [],
        'quotes': [],
        'retweets': [],
        'comments': []
    }

    for tweet in tweets['tweets']:
        data['link'].append(tweet['link'])
        data['text'].append(tweet['text'])
        data['user'].append(tweet['user']['username'])
        data['likes'].append(tweet['stats']['likes'])
        data['quotes'].append(tweet['stats']['quotes'])
        data['retweets'].append(tweet['stats']['retweets'])
        data['comments'].append(tweet['stats']['comments'])

    df2 = pd.DataFrame(data)
    return df2
     # df.to_csv(username+"_tweets_data.csv")

# %%
# Llamando a la función para obtener el DataFrame
df_tweets = create_tweets_dataset('julianalvarezzz', 100)
# Out:
# INFO:root:No instance specified, using random instance https://nitter.privacydev.net
# INFO:root:Current stats for julianalvarezzz: 20 tweets, 0 threads...
# INFO:root:Current stats for julianalvarezzz: 40 tweets, 0 threads...
# INFO:root:Current stats for julianalvarezzz: 60 tweets, 0 threads...
# INFO:root:Current stats for julianalvarezzz: 80 tweets, 0 threads...
# WARNING:root:Empty page on https://nitter.privacydev.net

# %%
df_tweets.head()
# Out:
#                                                 link  \
# 0  https://twitter.com/julianalvarezzz/status/159...
# 1  https://twitter.com/ManCity/status/15890197275...
# 2  https://twitter.com/ManCityES/status/158792286...
# 3  https://twitter.com/ManCityPT/status/158794472...
# 4  https://twitter.com/julianalvarezzz/status/157...
#
#                                                 text              user  \
# 0                Vamos Argentina! 🇦🇷 Todos juntos 💪🏻  @julianalvarezzz
# 1  La Araña strikes again! 🕷  @julianalvarezzz wi...          @ManCity
# 2  📸 Secuencia del gol de @julianalvarezzz 🤟🕷️  🔵...        @ManCityES
# 3                       🕷️🕷️🕷️🕷️🕷️🕷️🕷️🕷️🕷️🕷️🕷️🕷️🕷️🕷️        @ManCityPT
# 4  Ultima gira previa al mundial 💪🏻 Gracias a tod...  @julianalvarezzz
#
#     likes  quotes  retweets  comments
# 0  103155     330      5116       785
# 1   15918     103       915       142
# 2    7543      13       373        43
# 3   19046      57       886        59
# 4   67496     312      2557       562

# %%
##poniendolo como df es como mejor contesta....

contexto2 = f"""Sos un agente de social media de una empresa de futbol, te dan la siguiente informarcion:  {df_tweets}, que contiene tweets para que comiences tu analisis informacion sobre el perfil de un jugador de futbol obtenido de twitter."""


pregunta2 = f""" Tu trabajo es informarnos cuantos tweets tiene, seguidores, likes y toda la informacion que consideres relavante. Solamente utilizando los datos que estan aqui"""

# Prompt con el contexto y la pregunta
prompt2 = f"{contexto2}\n\n{pregunta2}"

# Generar la respuesta utilizando el prompt actualizado
responses2 = model.generate_content(prompt2, generation_config=generation_config, stream=True)

# Imprimir la respuesta generada
  # Genera la respuesta
for response in responses2:
    print(response.text, end="")

# %%
contexto3 = f"""Sos un agente de social media de una empresa de futbol, te dan la siguiente informarcion:  {df_tweets}, que contiene tweets para que comiences tu analisis informacion sobre el perfil de un jugador de futbol obtenido de twitter."""


pregunta3 = f""" Tu trabajo es darnos un informe de social media, en base a tweets, likes, quotes, retweets, comments. Que podrias decir sobre la imagen del jugador si es positiva, negativa o neutra. """

# Prompt con el contexto y la pregunta
prompt3 = f"{contexto3}\n\n{pregunta3}"

# Generar la respuesta utilizando el prompt actualizado
responses3 = model.generate_content(prompt3, generation_config=generation_config, stream=True)

# Imprimir la respuesta generada
  # Genera la respuesta
for response in responses3:
    print(response.text, end="")

# %% [markdown]
# Pruebo poniendo term no me da....

# %% [markdown]
# Con hashtag

# %%
hash= scraper.get_tweets("github", mode="hashtag", number=10)   #, since="2024-06-19", to="2024-07-19")
# Out:
# INFO:root:No instance specified, using random instance https://nitter.privacydev.net
# WARNING:root:Empty page on https://nitter.privacydev.net

# %%
####no anda porque esta bloqueadoooo

# %%
# !pip install snscrape
# Out:
# Collecting snscrape
#   Downloading snscrape-0.7.0.20230622-py3-none-any.whl (74 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 74.8/74.8 kB 1.6 MB/s eta 0:00:00
# Requirement already satisfied: requests[socks] in /usr/local/lib/python3.10/dist-packages (from snscrape) (2.31.0)
# Requirement already satisfied: lxml in /usr/local/lib/python3.10/dist-packages (from snscrape) (4.9.4)
# Requirement already satisfied: beautifulsoup4 in /usr/local/lib/python3.10/dist-packages (from snscrape) (4.12.3)
# Requirement already satisfied: filelock in /usr/local/lib/python3.10/dist-packages (from snscrape) (3.15.4)
# Requirement already satisfied: soupsieve>1.2 in /usr/local/lib/python3.10/dist-packages (from beautifulsoup4->snscrape) (2.5)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.10/dist-packages (from requests[socks]->snscrape) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.10/dist-packages (from requests[socks]->snscrape) (3.7)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.10/dist-packages (from requests[socks]->snscrape) (2.0.7)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.10/dist-packages (from requests[socks]->snscrape) (2024.7.4)
# Requirement already satisfied: PySocks!=1.5.7,>=1.5.6 in /usr/local/lib/python3.10/dist-packages (from requests[socks]->snscrape) (1.7.1)
# Installing collected packages: snscrape
# Successfully installed snscrape-0.7.0.20230622

# %%
import pandas as pd
from tqdm.notebook import tqdm
import snscrape.modules.twitter as sntwitter

# %%
scraper

# %%
scraper= sntwitter.TwitterSearchScraper('#julian alvarez')  ##hay mas funciones

# %%
for tweet in scraper.get_items():
  break
# Out:
# ERROR:snscrape.base:Error retrieving https://twitter.com/i/api/graphql/7jT5GT59P8IFjgxwqnEdQw/SearchTimeline?variables=%7B%22rawQuery%22%3A%22%23julian%20alvarez%22%2C%22count%22%3A20%2C%22product%22%3A%22Latest%22%2C%22withDownvotePerspective%22%3Afalse%2C%22withReactionsMetadata%22%3Afalse%2C%22withReactionsPerspective%22%3Afalse%7D&features=%7B%22rweb_lists_timeline_redesign_enabled%22%3Afalse%2C%22blue_business_profile_image_shape_enabled%22%3Afalse%2C%22responsive_web_graphql_exclude_directive_enabled%22%3Atrue%2C%22verified_phone_label_enabled%22%3Afalse%2C%22creator_subscriptions_tweet_preview_api_enabled%22%3Afalse%2C%22responsive_web_graphql_timeline_navigation_enabled%22%3Atrue%2C%22responsive_web_graphql_skip_user_profile_image_extensions_enabled%22%3Afalse%2C%22tweetypie_unmention_optimization_enabled%22%3Atrue%2C%22vibe_api_enabled%22%3Atrue%2C%22responsive_web_edit_tweet_api_enabled%22%3Atrue%2C%22graphql_is_translatable_rweb_tweet_is_translatable_enabled%22%3Atrue%2C%22view_counts_everywhere_api_enabled%22%3Atrue%2C%22longform_notetweets_consumption_enabled%22%3Atrue%2C%22tweet_awards_web_tipping_enabled%22%3Afalse%2C%22freedom_of_speech_not_reach_fetch_enabled%22%3Afalse%2C%22standardized_nudges_misinfo%22%3Atrue%2C%22tweet_with_visibility_results_prefer_gql_limited_actions_policy_enabled%22%3Afalse%2C%22interactive_text_enabled%22%3Atrue%2C%22responsive_web_text_conversations_enabled%22%3Afalse%2C%22longform_notetweets_rich_text_read_enabled%22%3Afalse%2C%22longform_notetweets_inline_media_enabled%22%3Afalse%2C%22responsive_web_enhance_cards_enabled%22%3Afalse%2C%22responsive_web_twitter_blue_verified_badge_is_enabled%22%3Atrue%7D: blocked (404)
# CRITICAL:snscrape.base:4 requests to https://twitter.com/i/api/graphql/7jT5GT59P8IFjgxwqnEdQw/SearchTimeline?variables=%7B%22rawQuery%22%3A%22%23julian%20alvarez%22%2C%22count%22%3A20%2C%22product%22%3A%22Latest%22%2C%22withDownvotePerspective%22%3Afalse%2C%22withReactionsMetadata%22%3Afalse%2C%22withReactionsPerspective%22%3Afalse%7D&features=%7B%22rweb_lists_timeline_redesign_enabled%22%3Afalse%2C%22blue_business_profile_image_shape_enabled%22%3Afalse%2C%22responsive_web_graphql_exclude_directive_enabled%22%3Atrue%2C%22verified_phone_label_enabled%22%3Afalse%2C%22creator_subscriptions_tweet_preview_api_enabled%22%3Afalse%2C%22responsive_web_graphql_timeline_navigation_enabled%22%3Atrue%2C%22responsive_web_graphql_skip_user_profile_image_extensions_enabled%22%3Afalse%2C%22tweetypie_unmention_optimization_enabled%22%3Atrue%2C%22vibe_api_enabled%22%3Atrue%2C%22responsive_web_edit_tweet_api_enabled%22%3Atrue%2C%22graphql_is_translatable_rweb_tweet_is_translatable_enabled%22%3Atrue%2C%22view_counts_everywhere_api_enabled%22%3Atrue%2C%22longform_notetweets_consumption_enabled%22%3Atrue%2C%22tweet_awards_web_tipping_enabled%22%3Afalse%2C%22freedom_of_speech_not_reach_fetch_enabled%22%3Afalse%2C%22standardized_nudges_misinfo%22%3Atrue%2C%22tweet_with_visibility_results_prefer_gql_limited_actions_policy_enabled%22%3Afalse%2C%22interactive_text_enabled%22%3Atrue%2C%22responsive_web_text_conversations_enabled%22%3Afalse%2C%22longform_notetweets_rich_text_read_enabled%22%3Afalse%2C%22longform_notetweets_inline_media_enabled%22%3Afalse%2C%22responsive_web_enhance_cards_enabled%22%3Afalse%2C%22responsive_web_twitter_blue_verified_badge_is_enabled%22%3Atrue%7D failed, giving up.
# CRITICAL:snscrape.base:Errors: blocked (404), blocked (404), blocked (404), blocked (404)
# ---------------------------------------------------------------------------
# ScraperException                          Traceback (most recent call last)
# <ipython-input-13-5add027ef596> in <cell line: 1>()
# ----> 1 for tweet in scraper.get_items():
#       2   break
#
# /usr/local/lib/python3.10/dist-packages/snscrape/modules/twitter.py in get_items(self)
#    1761                 paginationParams = {'variables': paginationVariables, 'features': features}
#    1762
# -> 1763                 for obj in self._iter_api_data('https://twitter.com/i/api/graphql/7jT5GT59P8IFjgxwqnEdQw/SearchTimeline', _TwitterAPIType.GRAPHQL, params, paginationParams, cursor = self._cursor, instructionsPath = ['data', 'search_by_raw_query', 'search_timeline', 'timeline', 'instructions']):
#    1764                         yield from self._graphql_timeline_instructions_to_tweets(obj['data']['search_by_raw_query']['search_timeline']['timeline']['instructions'])
#    1765
#
# /usr/local/lib/python3.10/dist-packages/snscrape/modules/twitter.py in _iter_api_data(self, endpoint, apiType, params, paginationParams, cursor, direction, instructionsPath)
#     913                 while True:
#     914                         _logger.info(f'Retrieving scroll page {cursor}')
# --> 915                         obj = self._get_api_data(endpoint, apiType, reqParams, instructionsPath = instructionsPath)
#     916                         yield obj
#     917
#
# /usr/local/lib/python3.10/dist-packages/snscrape/modules/twitter.py in _get_api_data(self, endpoint, apiType, params, instructionsPath)
#     884                 if apiType is _TwitterAPIType.GRAPHQL:
#     885                         params = urllib.parse.urlencode({k: json.dumps(v, separators = (',', ':')) for k, v in params.items()}, quote_via = urllib.parse.quote)
# --> 886                 r = self._get(endpoint, params = params, headers = self._apiHeaders, responseOkCallback = functools.partial(self._check_api_response, apiType = apiType, instructionsPath = instructionsPath))
#     887                 return r._snscrapeObj
#     888
#
# /usr/local/lib/python3.10/dist-packages/snscrape/base.py in _get(self, *args, **kwargs)
#     273
#     274         def _get(self, *args, **kwargs):
# --> 275                 return self._request('GET', *args, **kwargs)
#     276
#     277         def _post(self, *args, **kwargs):
#
# /usr/local/lib/python3.10/dist-packages/snscrape/base.py in _request(self, method, url, params, data, headers, timeout, responseOkCallback, allowRedirects, proxies)
#     269                         _logger.fatal(msg)
#     270                         _logger.fatal(f'Errors: {", ".join(errors)}')
# --> 271                         raise ScraperException(msg)
#     272                 raise RuntimeError('Reached unreachable code')
#     273
#
# ScraperException: 4 requests to https://twitter.com/i/api/graphql/7jT5GT59P8IFjgxwqnEdQw/SearchTimeline?variables=%7B%22rawQuery%22%3A%22%23julian%20alvarez%22%2C%22count%22%3A20%2C%22product%22%3A%22Latest%22%2C%22withDownvotePerspective%22%3Afalse%2C%22withReactionsMetadata%22%3Afalse%2C%22withReactionsPerspective%22%3Afalse%7D&features=%7B%22rweb_lists_timeline_redesign_enabled%22%3Afalse%2C%22blue_business_profile_image_shape_enabled%22%3Afalse%2C%22responsive_web_graphql_exclude_directive_enabled%22%3Atrue%2C%22verified_phone_label_enabled%22%3Afalse%2C%22creator_subscriptions_tweet_preview_api_enabled%22%3Afalse%2C%22responsive_web_graphql_timeline_navigation_enabled%22%3Atrue%2C%22responsive_web_graphql_skip_user_profile_image_extensions_enabled%22%3Afalse%2C%22tweetypie_unmention_optimization_enabled%22%3Atrue%2C%22vibe_api_enabled%22%3Atrue%2C%22responsive_web_edit_tweet_api_enabled%22%3Atrue%2C%22graphql_is_translatable_rweb_tweet_is_translatable_enabled%22%3Atrue%2C%22view_counts_everywhere_api_enabled%22%3Atrue%2C%22longform_notetweets_consumption_enabled%22%3Atrue%2C%22tweet_awards_web_tipping_enabled%22%3Afalse%2C%22freedom_of_speech_not_reach_fetch_enabled%22%3Afalse%2C%22standardized_nudges_misinfo%22%3Atrue%2C%22tweet_with_visibility_results_prefer_gql_limited_actions_policy_enabled%22%3Afalse%2C%22interactive_text_enabled%22%3Atrue%2C%22responsive_web_text_conversations_enabled%22%3Afalse%2C%22longform_notetweets_rich_text_read_enabled%22%3Afal...

# %%
tweet.date, tweet.id, tweet.content, tweet.user.username
